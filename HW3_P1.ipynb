# %% [markdown]
# <a href="https://colab.research.google.com/github/Arko04/Colab/blob/main/HW3_P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="display:block;width:100%;margin:auto;" direction=rtl align=center><br><br>
#     <div  style="width:100%;margin:100;display:block;background-color:#fff0;"  display=block align=center>
#         <table style="border-style:hidden;border-collapse:collapse;">
#             <tr>
#                 <td  style="border: none!important;">
#         <img width=230 align=right src="https://i.ibb.co/yXKQmtZ/logo1.png" style="margin:0;" />
#                 </td>
#                 <td style="text-align:center;border: none!important;">
#                 <h1 align=center><font size=5 color="#045F5F"> <b>HomeWork3-Part1</b><br><br>AliMosReza</i></font></h1>
#                 </td>
#                 <td style="border: none!important;">
#         <img width=300 align=left  src="https://i.ibb.co/wLjqFkw/logo2.png" style="margin:0;" />
#                 </td>
#             </tr>
#         </table>

# %% [markdown]
# ## **$I.$ Introduction and summary**

# %% [markdown]
# ### **In part1** we use **Soft-sign, sigmoid and hyperbolic tangent** activation functions:

# %% [markdown]
# $$ Sigmoid function (Logistic function):$$
# $$ f(x) = \frac{1}{1 + e^{-x}}$$
# $$ $$
#
# $$ Hyperbolic tangent (tanh) function: $$
# $$ f(x) = \tanh(x) = \frac{e^{x} - e^{-x}}{e^{x} + e^{-x}} $$
# $$ $$
#
# $$ Softsign function: $$
# $$ f(x) = \frac{x}{1 + |x|} $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the sigmoid function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Define the hyperbolic tangent function (tanh)
def tanh(x):
    return np.tanh(x)

# Define the softsign function
def softsign(x):
    return x / (1 + np.abs(x))

# Generate x values
x = np.linspace(-10, 10, 100)

# Calculate y values using the sigmoid, tanh, and softsign functions
y_sigmoid = sigmoid(x)
y_tanh = tanh(x)
y_softsign = softsign(x)

# Plot all three functions
plt.figure(figsize=(8, 6))
plt.plot(x, y_sigmoid, label='Sigmoid Function', color='blue')
plt.plot(x, y_tanh, label='Hyperbolic Tangent (tanh)', color='red', linestyle='--')
plt.plot(x, y_softsign, label='Softsign Function', color='green', linestyle=':')
plt.title('Plot of Sigmoid, Tanh, and Softsign Functions')
plt.xlabel('x')
plt.ylabel('Function Value')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# We also initialized the biases to be 0 and the weights Wij at
# each layer with the below formula:
# $$ W_{i,j} \sim U[(\frac {-1}{\sqrt{n}}),(\frac {1}{\sqrt{n}})]$$
#
# * $U[−a, a]$ is the uniform distribution in the interval $(−a, a)$
# *  $n$ is the size of the previous layer (the number
# of columns of $W$)
# * $W_{i,j}$ is every weight of each layer

# %% [markdown]
# ### **In part2** we use **ReLU, Leaky ReLU and PReLU** activation functions:

# %% [markdown]
# $$ReLU (Rectified Linear Unit) function:\\
# f(x) = \max(0, x) \\
# $$
#
# $$ PReLU (Parametric ReLU) function:
#  f(x) = \begin{cases}
#  x & \text{if } x > 0 \\
#  ax & \text{if } x \leq 0
#  \end{cases}
#  $$
#  $$ $$
#
# $$Leaky ReLU function:
#  f(x) = \begin{cases}
#  x & \text{if } x > 0 \\
#  ax & \text{if } x \leq 0
#  \end{cases}$$

# %%
# Define ReLU function
def relu(x):
    return np.maximum(0, x)

# Define PReLU function with parameter 'a'
def prelu(x, a):
    return np.where(x > 0, x, a * x)

# Define Leaky ReLU function with parameter 'a'
def leaky_relu(x, a):
    return np.where(x > 0, x, a * x)

# Generate input values
x = np.linspace(-10, 10, 100)

# Generate output values for each function
y_relu = relu(x)
y_prelu = prelu(x, 0.1)  # Assuming parameter 'a' as 0.1 for PReLU
y_leaky_relu = leaky_relu(x, 0.01)  # Assuming parameter 'a' as 0.01 for Leaky ReLU

# Plot ReLU, PReLU, and Leaky ReLU
plt.figure(figsize=(8, 6))
plt.plot(x, y_relu, label='ReLU', color='blue')
plt.plot(x, y_prelu, label='PReLU (a=0.1)', color='red', linestyle='--')
plt.plot(x, y_leaky_relu, label='Leaky ReLU (a=0.01)', color='green', linestyle='-.')
plt.title('Plot of ReLU, PReLU, and Leaky ReLU Functions')
plt.xlabel('x')
plt.ylabel('Output')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bebcb5d0a0e4> in <cell line: 14>()
#      12
#      13 # Generate input values
# ---> 14 x = np.linspace(-10, 10, 100)
#      15
#      16 # Generate output values for each function
#
# NameError: name 'np' is not defined

# %% [markdown]
# And here is architectures of large models in part2's initialization scheme:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * all biases are initialized at 0
# * All $W_{i,j}$ are mutually independant and have a random distribution symmetrical around $0$ (e.g. $W_{i,j} \sim U(-k, k)$ or $W_{i,j} \sim \mathcal{N}(0, \sigma)$ and the distribution is the identical within weights in the same layer of our neural network

# %% [markdown]
# ## **$II.$ Xavier Glorot and Yoshua Bengio's initialization scheme**

# %% [markdown]
# ## **$III.$ Kaiming He, Xiangyu Zhang, Shaoqing Ren, and Jian Sun initialization scheme**

# %% [markdown]
# ## **$IV.$ Compare two initialization schemes**

# %%
from google.colab import drive
drive.mount('/content/grive')
# Out:
# Drive already mounted at /content/grive; to attempt to forcibly remount, call drive.mount("/content/grive", force_remount=True).

# %%
from IPython.display import Image

# %%
Image(filename='/content/grive/MyDrive/HW3_P1/Slides/activation_function.jpeg', width=600,height=400)

# %%
Image(filename='/content/grive/MyDrive/HW3_P1/Slides/activation_functions.png', width=900,height=400)

# %%
import pandas as pd
import numpy as np

# %%
from tensorflow.keras.datasets import cifar10

# data = mnist.load_data()
data = cifar10.load_data()

# %% [markdown]
# source: https://www.analyticsvidhya.com/blog/2021/06/mnist-dataset-prediction-using-keras/

# %%
data
# Out:
# ((array([[[[ 59,  62,  63],
#            [ 43,  46,  45],
#            [ 50,  48,  43],
#            ...,
#            [158, 132, 108],
#            [152, 125, 102],
#            [148, 124, 103]],
#
#           [[ 16,  20,  20],
#            [  0,   0,   0],
#            [ 18,   8,   0],
#            ...,
#            [123,  88,  55],
#            [119,  83,  50],
#            [122,  87,  57]],
#
#           [[ 25,  24,  21],
#            [ 16,   7,   0],
#            [ 49,  27,   8],
#            ...,
#            [118,  84,  50],
#            [120,  84,  50],
#            [109,  73,  42]],
#
#           ...,
#
#           [[208, 170,  96],
#            [201, 153,  34],
#            [198, 161,  26],
#            ...,
#            [160, 133,  70],
#            [ 56,  31,   7],
#            [ 53,  34,  20]],
#
#           [[180, 139,  96],
#            [173, 123,  42],
#            [186, 144,  30],
#            ...,
#            [184, 148,  94],
#            [ 97,  62,  34],
#            [ 83,  53,  34]],
#
#           [[177, 144, 116],
#            [168, 129,  94],
#            [179, 142,  87],
#            ...,
#            [216, 184, 140],
#            [151, 118,  84],
#            [123,  92,  72]]],
#
#
#          [[[154, 177, 187],
#            [126, 137, 136],
#            [105, 104,  95],
#            ...,
#            [ 91,  95,  71],
#            [ 87,  90,  71],
#            [ 79,  81,  70]],
#
#           [[140, 160, 169],
#            [145, 153, 154],
#            [125, 125, 118],
#            ...,
#            [ 96,  99,  78],
#            [ 77,  80,  62],
#            [ 71,  73,  61]],
#
#           [[140, 155, 164],
#            [139, 146, 149],
#            [115, 115, 112],
#            ...,
#            [ 79,  82,  64],
#            [ 68,  70,  55],
#            [ 67,  69,  55]],
#
#           ...,
#
#           [[175, 167, 166],
#            [156, 154, 160],
#            [154, 160, 170],
#            ...,
#            [ 42,  34,  36],
#            [ 61,  53,  57],
#            [ 93,  83,  91]],
#
#           [[165, 154, 128],
#            [156, 152, 130],
#            [159, 161, 142],
#            ...,
#            [103,  93,  96],
#            [123, 114, 120],
#            [131, 121, 131]],
#
#           [[163, 148, 120],
#            [158, 148, 122],
#            [163, 156, 133],
#            ...,
#            [143, 133, 139],
#            [143, 134, 142],
#            [143, 133, 144]]],
#
#
#          [[[255, 255, 255],
#            [253, 253, 253],
#            [253, 253, 253],
#            ...,
#            [253, 253, 253],
#            [253, 253, 253],
#            [253, 253, 253]],
#
#           [[255, 255, 255],
#            [255, 255, 255],
#            [255, 255, 255],
#            ...,
#            [255, 255, 255],
#            [255, 255, 255],
#            [255, 255, 255]],
#
#           [[255, 255, 255],
#            [254, 254, 254],
#            [254, 254, 254],
#            ...,
#            [254, 254, 254],
#            [254, 254, 254],
#            [254, 254, 254]],
#
#           ...,
#
#           [[113, 120, 112],
#            [111, 118, 111],
#            [105, 112, 106],
#            ...,
#            [ 72,  81,  80],
#            [ 72,  80,  79],
#            [ 72,  80,  79]],
#
#           [[111, 118, 110],
#            [104, 111, 104],
#            [ 99, 106,  98],
#            ...,
#            [ 68,  75,  73],
#            [ 70,  76,  75],
#            [ 78,  84,  82]],
#
#           [[106, 113, 105],
#            [ 99, 106,  98],
#            [ 95, 102,  94],
#            ...,
#            [ 78,  85,  83],
#            [ 79,  85,  83],
#            [ 80,  86,  84]]],
#
#
#          ...,
#
#
#          [[[ 35, 178, 235],
#            [ 40, 176, 239],
#            [ 42, 176, 241],
#            ...,
#            [ 99, 177, 219],
#            [ 79, 147, 197],
#            [ 89, 148, 189]],
#
#           [[ 57, 182, 234],
#            [ 44, 184, 250],
#            [ 50, 183, 240],
#            ...,
#            [156, 182, 200],
#            [141, 177, 206],
#            [116, 149, 175]],
#
#           [[ 98, 197, 237],
#            [ 64, 189, 252],
#            [ 69, 192, 245],
#            ...,
#            [188, 195, 206],
#            [119, 135, 147],
#            [ 61,  79,  90]],
#
#           ...,
#
#           [[ 73,  79,  77],
#            [ 53,  63,  68],
#            [ 54,  68,  80],
#            ...,
#            [ 17,  40,  64],
#            [ 21,  36,  51],
#            [ 33,  48,  49]],
#
#           [[ 61,  68,  75],
#            [ 55,  70,  86],
#            [ 57,  79, 103],
#            ...,
#            [ 24,  48,  72],
#            [ 17,  35,  53],
#            [  7,  23,  32]],
#
#           [[ 44,  56,  73],
#            [ 46,  66,  88],
#            [ 49,  77, 105],
#            ...,
#            [ 27,  52,  77],
#            [ 21,  43,  66],
#            [ 12,  31,  50]]],
#
#
#          [[[189, 211, 240],
#            [186, 208, 236],
#            [185, 207, 235],
#            ...,
#            [175, 195, 224],
#            [172, 194, 222],
#            [169, 194, 220]],
#
#           [[194, 210, 239],
#            [191, 207, 236],
#            [190, 206, 235],
#            ...,
#            [173, 192, 220],
#            [171, 191, 218],
#            [167, 190, 216]],
#
#           [[208, 219, 244],
#            [205, 216, 240],
#            [204, 215, 239],
#            ...,
#            [175, 191, 217],
#            [172, 190, 216],
#            [169, 191, 215]],
#
#           ...,
#
#           [[207, 199, 181],
#            [203, 195, 175],
#            [203, 196, 173],
#            ...,
#            [135, 132, 127],
#            [162, 158, 150],
#            [168, 163, 151]],
#
#           [[198, 190, 170],
#            [189, 181, 159],
#            [180, 172, 147],
#            ...,
#            [178, 171, 160],
#            [175, 169, 156],
#            [175, 169, 154]],
#
#           [[198, 189, 173],
#            [189, 181, 162],
#            [178, 170, 149],
#            ...,
#            [195, 184, 169],
#            [196, 189, 171],
#            [195, 190, 171]]],
#
#
#          [[[229, 229, 239],
#            [236, 237, 247],
#            [234, 236, 247],
#            ...,
#            [217, 219, 233],
#            [221, 223, 234],
#            [222, 223, 233]],
#
#           [[222, 221, 229],
#            [239, 239, 249],
#            [233, 234, 246],
#            ...,
#            [223, 223, 236],
#            [227, 228, 238],
#            [210, 211, 220]],
#
#           [[213, 206, 211],
#            [234, 232, 239],
#            [231, 233, 244],
#            ...,
#            [220, 220, 232],
#            [220, 219, 232],
#            [202, 203, 215]],
#
#           ...,
#
#           [[150, 143, 135],
#            [140, 135, 127],
#            [132, 127, 120],
#            ...,
#            [224, 222, 218],
#            [230, 228, 225],
#            [241, 241, 238]],
#
#           [[137, 132, 126],
#            [130, 127, 120],
#            [125, 121, 115],
#            ...,
#            [181, 180, 178],
#            [202, 201, 198],
#            [212, 211, 207]],
#
#           [[122, 119, 114],
#            [118, 116, 110],
#            [120, 116, 111],
#            ...,
#            [179, 177, 173],
#            [164, 164, 162],
#            [163, 163, 161]]]], dtype=uint8),
#   array([[6],
#          [9],
#          [9],
#          ...,
#          [9],
#          [1],
#          [1]], dtype=uint8)),
#  (array([[[[158, 112,  49],
#            [159, 111,  47],
#            [165, 116,  51],
#            ...,
#            [137,  95,  36],
#            [126,  91,  36],
#            [116,  85,  33]],
#
#           [[152, 112,  51],
#            [151, 110,  40],
#            [159, 114,  45],
#            ...,
#            [136,  95,  31],
#            [125,  91,  32],
#            [119,  88,  34]],
#
#           [[151, 110,  47],
#            [151, 109,  33],
#            [158, 111,  36],
#            ...,
#            [139,  98,  34],
#            [130,  95,  34],
#            [120,  89,  33]],
#
#           ...,
#
#           [[ 68, 124, 177],
#            [ 42, 100, 148],
#            [ 31,  88, 137],
#            ...,
#            [ 38,  97, 146],
#            [ 13,  64, 108],
#            [ 40,  85, 127]],
#
#           [[ 61, 116, 168],
#            [ 49, 102, 148],
#            [ 35,  85, 132],
#            ...,
#            [ 26,  82, 130],
#            [ 29,  82, 126],
#            [ 20,  64, 107]],
#
#           [[ 54, 107, 160],
#            [ 56, 105, 149],
#            [ 45,  89, 132],
#            ...,
#            [ 24,  77, 124],
#            [ 34,  84, 129],
#            [ 21,  67, 110]]],
#
#
#          [[[235, 235, 235],
#            [231, 231, 231],
#            [232, 232, 232],
#            ...,
#            [233, 233, 233],
#            [233, 233, 233],
#            [232, 232, 232]],
#
#           [[238, 238, 238],
#            [235, 235, 235],
#            [235, 235, 235],
#            ...,
#            [236, 236, 236],
#            [236, 236, 236],
#            [235, 235, 235]],
#
#           [[237, 237, 237],
#            [234, 234, 234],
#            [234, 234, 234],
#            ...,
#            [235, 235, 235],
#            [235, 235, 235],
#            [234, 234, 234]],
#
#           ...,
#
#           [[ 87,  99,  89],
#            [ 43,  51,  37],
#            [ 19,  23,  11],
#            ...,
#            [169, 184, 179],
#            [182, 197, 193],
#            [188, 202, 201]],
#
#           [[ 82,  96,  82],
#            [ 46,  57,  36],
#            [ 36,  44,  22],
#            ...,
#            [174, 189, 183],
#            [185, 200, 196],
#            [187, 202, 200]],
#
#           [[ 85, 101,  83],
#            [ 62,  75,  48],
#            [ 58,  67,  38],
#            ...,
#            [168, 183, 178],
#            [180, 195, 191],
#            [186, 200, 199]]],
#
#
#          [[[158, 190, 222],
#            [158, 187, 218],
#            [139, 166, 194],
#            ...,
#            [228, 231, 234],
#            [237, 239, 243],
#            [238, 241, 246]],
#
#           [[170, 200, 229],
#            [172, 199, 226],
#            [151, 176, 201],
#            ...,
#            [232, 232, 236],
#            [246, 246, 250],
#            [246, 247, 251]],
#
#           [[174, 201, 225],
#            [176, 200, 222],
#            [157, 179, 199],
#            ...,
#            [230, 229, 232],
#            [250, 249, 251],
#            [245, 244, 247]],
#
#           ...,
#
#           [[ 31,  40,  45],
#            [ 30,  39,  44],
#            [ 26,  35,  40],
#            ...,
#            [ 37,  40,  46],
#            [  9,  13,  14],
#            [  4,   7,   5]],
#
#           [[ 23,  34,  39],
#            [ 27,  38,  43],
#            [ 25,  36,  41],
#            ...,
#            [ 19,  20,  24],
#            [  4,   6,   3],
#            [  5,   7,   3]],
#
#           [[ 28,  41,  47],
#            [ 30,  43,  50],
#            [ 32,  45,  52],
#            ...,
#            [  5,   6,   8],
#            [  4,   5,   3],
#            [  7,   8,   7]]],
#
#
#          ...,
#
#
#          [[[ 20,  15,  12],
#            [ 19,  14,  11],
#            [ 15,  14,  11],
#            ...,
#            [ 10,   9,   7],
#            [ 12,  11,   9],
#            [ 13,  12,  10]],
#
#           [[ 21,  16,  13],
#            [ 20,  16,  13],
#            [ 18,  17,  12],
#            ...,
#            [ 10,   9,   7],
#            [ 10,   9,   7],
#            [ 12,  11,   9]],
#
#           [[ 21,  16,  13],
#            [ 21,  17,  12],
#            [ 20,  18,  11],
#            ...,
#            [ 12,  11,   9],
#            [ 12,  11,   9],
#            [ 13,  12,  10]],
#
#           ...,
#
#           [[ 33,  25,  13],
#            [ 34,  26,  15],
#            [ 34,  26,  15],
#            ...,
#            [ 28,  25,  52],
#            [ 29,  25,  58],
#            [ 23,  20,  42]],
#
#           [[ 33,  25,  14],
#            [ 34,  26,  15],
#            [ 34,  26,  15],
#            ...,
#            [ 27,  24,  52],
#            [ 27,  24,  56],
#            [ 25,  22,  47]],
#
#           [[ 31,  23,  12],
#            [ 32,  24,  13],
#            [ 33,  25,  14],
#            ...,
#            [ 24,  23,  50],
#            [ 26,  23,  53],
#            [ 25,  20,  47]]],
#
#
#          [[[ 25,  40,  12],
#            [ 15,  36,   3],
#            [ 23,  41,  18],
#            ...,
#            [ 61,  82,  78],
#            [ 92, 113, 112],
#            [ 75,  89,  92]],
#
#           [[ 12,  25,   6],
#            [ 20,  37,   7],
#            [ 24,  36,  15],
#            ...,
#            [115, 134, 138],
#            [149, 168, 177],
#            [104, 117, 131]],
#
#           [[ 12,  25,  11],
#            [ 15,  29,   6],
#            [ 34,  40,  24],
#            ...,
#            [154, 172, 182],
#            [157, 175, 192],
#            [116, 129, 151]],
#
#           ...,
#
#           [[100, 129,  81],
#            [103, 132,  84],
#            [104, 134,  86],
#            ...,
#            [ 97, 128,  84],
#            [ 98, 126,  84],
#            [ 91, 121,  79]],
#
#           [[103, 132,  83],
#            [104, 131,  83],
#            [107, 135,  87],
#            ...,
#            [101, 132,  87],
#            [ 99, 127,  84],
#            [ 92, 121,  79]],
#
#           [[ 95, 126,  78],
#            [ 95, 123,  76],
#            [101, 128,  81],
#            ...,
#            [ 93, 124,  80],
#            [ 95, 123,  81],
#            [ 92, 120,  80]]],
#
#
#          [[[ 73,  78,  75],
#            [ 98, 103, 113],
#            [ 99, 106, 114],
#            ...,
#            [135, 150, 152],
#            [135, 149, 154],
#            [203, 215, 223]],
#
#           [[ 69,  73,  70],
#            [ 84,  89,  97],
#            [ 68,  75,  81],
#            ...,
#            [ 85,  95,  89],
#            [ 71,  82,  80],
#            [120, 133, 135]],
#
#           [[ 69,  73,  70],
#            [ 90,  95, 100],
#            [ 62,  71,  74],
#            ...,
#            [ 74,  81,  70],
#            [ 53,  62,  54],
#            [ 62,  74,  69]],
#
#           ...,
#
#           [[123, 128,  96],
#            [132, 132, 102],
#            [129, 128, 100],
#            ...,
#            [108, 107,  88],
#            [ 62,  60,  55],
#            [ 27,  27,  28]],
#
#           [[115, 121,  91],
#            [123, 124,  95],
#            [129, 126,  99],
#            ...,
#            [115, 116,  94],
#            [ 66,  65,  59],
#            [ 27,  27,  27]],
#
#           [[116, 120,  90],
#            [121, 122,  94],
#            [129, 128, 101],
#            ...,
#            [116, 115,  94],
#            [ 68,  65,  58],
#            [ 27,  26,  26]]]], dtype=uint8),
#   array([[3],
#          [8],
#          [8],
#          ...,
#          [5],
#          [1],
#          [7]], dtype=uint8)))

# %%
# import numpy as np
# import tensorflow as tf
# from tensorflow.keras.datasets import cifar10
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# # Load CIFAR-10 data
# (x_train, y_train), (x_test, y_test) = cifar10.load_data()

# # Function to resize images
# def resize_images(img):
#     return tf.image.resize(img, [224, 224]).numpy()

# # Resize training and test images
# x_train_resized = np.array([resize_images(x) for x in x_train])
# x_test_resized = np.array([resize_images(x) for x in x_test])

# # Normalize pixel values to be between 0 and 1
# x_train_resized, x_test_resized = x_train_resized / 255.0, x_test_resized / 255.0

# # Create ImageDataGenerator instances for augmenting training and test sets
# train_datagen = ImageDataGenerator(
#     rescale=1./255,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     horizontal_flip=True
# )

# test_datagen = ImageDataGenerator(rescale=1./255)

# # Create training and validation generators
# train_generator = train_datagen.flow(x_train_resized, y_train, batch_size=32)
# test_generator = test_datagen.flow(x_test_resized, y_test, batch_size=32)

# # Now, train_generator and test_generator are ready to be used in model training

# %%
# type(data)

# %%
(X_train, y_train), (X_test, y_test) = data

print(X_train.shape, y_train.shape)
print(X_train[0].shape)


print(X_test.shape, y_test.shape)
print(X_test[0].shape)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (32, 32, 3)
# (10000, 32, 32, 3) (10000, 1)
# (32, 32, 3)

# %%
from sklearn.model_selection import train_test_split

# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=10000, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# ###usage of 'random_state = 42':

# %% [markdown]
# The random_state parameter in the train_test_split function in Scikit-learn is used to set the seed for the random number generator, ensuring that the train and test datasets are split in the same way every time the code is executed. The value of random_state is arbitrary, and 42 is commonly used as a convention, based on its significance in popular culture as the "Answer to the Ultimate Question of Life, the Universe, and Everything" in Douglas Adams' science fiction novel "The Hitchhiker's Guide to the Galaxy."
# Using a fixed value for random_state ensures that the results of the model are reproducible, allowing for more consistent and reliable comparisons between different models and experiments. It is recommended to set the random_state parameter in Scikit-learn algorithms, including train_test_split, to ensure that the results are reproducible and can be validated by others.

# %% [markdown]
# You can set the random_state parameter to any integer value. The specific value you choose for random_state does not affect the quality of the split; it only determines the random seed used for the splitting process.

# %% [markdown]
# The difference between setting the random seed to 42 or 12 or any other number is that the sequence of random numbers generated will be different, but the property of reproducibility will remain the same.

# %% [markdown]
# source: https://www.perplexity.ai/search/i-wanted-to-BK42_k8oQbidEldYO5Ul.Q

# %%
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (40000, 32, 32, 3) (40000, 1)
# (10000, 32, 32, 3) (10000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
# X_train_copy = X_train.copy()
# X_val_copy = X_val.copy()
# X_test_copy = X_test.copy()

# X_train_copy = X_train_copy / 255.0
# X_val_copy = X_val_copy / 255.0
# X_test_copy = X_test_copy / 255.0

# Flatten the images and normalize the pixel values
# X_train = X_train.reshape(-1, 28, 28)
# X_val = X_val.reshape(-1, 28, 28)
# X_test = X_test.reshape(-1, 28, 28)

#Normalize the pixel values
# X_train = X_train / 255.0
# X_val = X_val / 255.0
# X_test = X_test / 255.0

X_train = X_train.astype('float32') / 255
X_val = X_val.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# %%
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (40000, 32, 32, 3) (40000, 1)
# (10000, 32, 32, 3) (10000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
from tensorflow import keras
from tensorflow.keras import initializers

def build_model(input_shape, hidden_size, output_size, number_of_hidden_layers, activation_func, initializer):
  model = keras.Sequential()

  model.add(keras.Input(shape=input_shape))

  for _ in range(number_of_hidden_layers):
    model.add(keras.layers.Dense(hidden_size, activation=activation_func, kernel_initializer=initializer))

  model.add(keras.layers.Dense(output_size, activation="softmax"))

  model.compile(optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
  return model

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
# from tensorflow.keras.layers import Dropout


# def vgg19_model(input_shape=(32, 32, 3), num_classes=10):
#   """
#   Builds a VGG19 model architecture from scratch.

#   Args:
#       input_shape: The shape of the input images (default: (224, 224, 3) for ImageNet).
#       num_classes: The number of output classes (default: 1000 for ImageNet).

#   Returns:
#       A compiled Keras Sequential model representing the VGG19 architecture.
#   """

#   model = Sequential([
#       # Block 1
#       Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=input_shape),
#       Conv2D(64, (3, 3), activation='relu', padding='same'),
#       MaxPooling2D((2, 2), strides=(2, 2)),

#       # Block 2
#       Conv2D(128, (3, 3), activation='relu', padding='same'),
#       Conv2D(128, (3, 3), activation='relu', padding='same'),
#       MaxPooling2D((2, 2), strides=(2, 2)),

#       # Block 3
#       Conv2D(256, (3, 3), activation='relu', padding='same'),
#       Conv2D(256, (3, 3), activation='relu', padding='same'),
#       Conv2D(256, (3, 3), activation='relu', padding='same'),
#       Conv2D(256, (3, 3), activation='relu', padding='same'),
#       MaxPooling2D((2, 2), strides=(2, 2)),

#       # Block 4
#       Conv2D(512, (3, 3), activation='relu', padding='same'),
#       Conv2D(512, (3, 3), activation='relu', padding='same'),
#       Conv2D(512, (3, 3), activation='relu', padding='same'),
#       Conv2D(512, (3, 3), activation='relu', padding='same'),
#       MaxPooling2D((2, 2), strides=(2, 2)),

#       # Block 5
#       Conv2D(512, (3, 3), activation='relu', padding='same'),
#       Conv2D(512, (3, 3), activation='relu', padding='same'),
#       Conv2D(512, (3, 3), activation='relu', padding='same'),
#       Conv2D(512, (3, 3), activation='relu', padding='same'),
#       MaxPooling2D((2, 2), strides=(2, 2)),

#       # Fully-connected layers
#       Flatten(),
#       Dense(4096, activation='relu'),
#       Dropout(0.5),
#       Dense(4096, activation='relu'),
#       Dropout(0.5),
#       Dense(num_classes, activation='softmax')
#   ])

#   # Compile the model (you can choose your optimizer and loss function)
#   model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#   return model

# # Example usage (assuming you have your image data loaded)
# # model = vgg19_model(input_shape=(your_image_shape), num_classes=your_num_classes)
# # model.fit(your_training_data, your_training_labels, epochs=your_epochs)

# %%
# pip install git+https://github.com/yhenon/keras-spp.git

# %%
# import tensorflow.keras.backend as K
# from tensorflow.keras.layers import Layer

# class SpatialPyramidPooling(Layer):
#     """Spatial pyramid pooling layer for 2D inputs.
#     See Spatial Pyramid Pooling in Deep Convolutional Networks for Visual Recognition,
#     K. He, X. Zhang, S. Ren, J. Sun
#     """

#     def __init__(self, pool_list, **kwargs):
#         self.data_format = K.image_data_format()
#         assert self.data_format in {'channels_last', 'channels_first'}, 'data_format must be in {channels_last, channels_first}'

#         self.pool_list = pool_list
#         self.num_outputs_per_channel = sum([i * i for i in pool_list])
#         super(SpatialPyramidPooling, self).__init__(**kwargs)

#     def build(self, input_shape):
#         if self.data_format == 'channels_first':
#             self.nb_channels = input_shape[1]
#         else:
#             self.nb_channels = input_shape[3]

#     def compute_output_shape(self, input_shape):
#         return (input_shape[0], self.nb_channels * self.num_outputs_per_channel)

#     def get_config(self):
#         config = {'pool_list': self.pool_list}
#         base_config = super().get_config()
#         return {**base_config, **config}

#     def call(self, x, mask=None):
#         input_shape = K.shape(x)
#         outputs = []
#         for pool_num, num_pool_regions in enumerate(self.pool_list):
#             for jy in range(num_pool_regions):
#                 for ix in range(num_pool_regions):
#                     if self.data_format == 'channels_first':
#                         # Implementation for channels_first
#                         pass
#                     else:
#                         # Implementation for channels_last
#                         pass

#         return K.concatenate(outputs)

# Add specific implementation details as required.
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Layer

class SpatialPyramidPooling(Layer):
    """Spatial pyramid pooling layer for 2D inputs."""

    def __init__(self, pool_list=[1, 2, 4], **kwargs):
        self.pool_list = pool_list
        self.num_outputs_per_channel = sum([i * i for i in pool_list])
        super(SpatialPyramidPooling, self).__init__(**kwargs)

    def build(self, input_shape):
        self.data_format = K.image_data_format()
        assert self.data_format in {'channels_last', 'channels_first'}, 'data_format must be in {channels_last, channels_first}'

        if self.data_format == 'channels_first':
            self.nb_channels = input_shape[1]
        else:
            self.nb_channels = input_shape[3]

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.nb_channels * self.num_outputs_per_channel)

    def get_config(self):
        config = {'pool_list': self.pool_list}
        base_config = super().get_config()
        return {**base_config, **config}

    def call(self, x, mask=None):
        input_shape = K.shape(x)
        outputs = []

        if self.data_format == 'channels_first':
            batch_size, channels, rows, cols = input_shape
        else:
            batch_size, rows, cols, channels = input_shape

        for pool_num, num_pool_regions in enumerate(self.pool_list):
            pool_size = int(rows / num_pool_regions)
            stride = pool_size

            for jy in range(num_pool_regions):
                for ix in range(num_pool_regions):
                    if self.data_format == 'channels_first':
                        x_strip = x[:, :, jy * stride:jy * stride + pool_size, ix * stride:ix * stride + pool_size]
                    else:
                        x_strip = x[:, jy * stride:jy * stride + pool_size, ix * stride:ix * stride + pool_size, :]

                    output = K.max(x_strip, axis=(2, 3)) if self.data_format == 'channels_first' else K.max(x_strip, axis=(1, 2))
                    outputs.append(output)

        outputs = tf.concat(outputs, axis=-1)
        return outputs

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, PReLU
# from tensorflow.keras.initializers import HeNormal
# from tensorflow.keras.layers import GlobalAveragePooling2D

# def make_model_A(input_shape=(32, 32, 3), num_classes=10):
#     """
#     Builds a VGG19 inspired model architecture modified according to the paper,
#     with PReLU activation and adjustments in convolutional layers' configuration.

#     Args:
#         input_shape: The shape of the input images.
#         num_classes: The number of output classes.

#     Returns:
#         A compiled Keras Sequential model.
#     """

#     model = Sequential()

#     # Initial Conv layer
#     model.add(Conv2D(96, (7, 7), strides=(2, 2), padding='same', input_shape=input_shape, kernel_initializer=HeNormal()))
#     model.add(PReLU())
#     model.add(MaxPooling2D((2, 2), strides=(2, 2)))

#     # Configurations for repetitive blocks
#     layer_configs = [
#         (256, 3, 3),  # parameters for the second set of layers
#         (512, 3, 3)   # parameters for the third set of layers
#     ]

#     # Adding repetitive blocks
#     for filters, repetitions in layer_configs:
#         for _ in range(repetitions):
#             model.add(Conv2D(filters, (3, 3), padding='same', kernel_initializer=HeNormal()))
#             model.add(PReLU())
#         model.add(MaxPooling2D((2, 2), strides=(2, 2)))

#     # Global Average Pooling
#     model.add(GlobalAveragePooling2D())

#     # Fully-connected

    # # Fully-connected Layers
    # model.add(Dense(4096, kernel_initializer=HeNormal()))
    # model.add(Dropout(0.5))
    # model.add(PReLU())
    # model.add(Dense(4096, kernel_initializer=HeNormal()))
    # model.add(Dropout(0.5))
    # model.add(PReLU())

    # # Output Layer
    # model.add(Dense(num_classes, activation='softmax'))

    # # Compile the model
    # model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    # return model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import PReLU
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.layers import GlobalAveragePooling2D  # Assuming Spatial Pyramid Pooling is similar

def make_model_A(input_shape=(32, 32, 3), num_classes=10):
    """
    Builds a VGG19 inspired model architecture modified according to the paper,
    with PReLU activation and adjustments in convolutional layers' configuration.

    Args:
        input_shape: The shape of the input images (default: (224, 224, 3) for ImageNet).
        num_classes: The number of output classes (default: 1000 for ImageNet).

    Returns:
        A compiled Keras Sequential model.
    """

    model = Sequential([
        # First conv layer with modified filter size and stride according to the paper.
        Conv2D(96, (7, 7), strides=(2, 2), padding='same', input_shape=input_shape, kernel_initializer=HeNormal()),
        PReLU(),

        # First pooling layer
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Second set of layers
        Conv2D(256, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third set of layers
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third set of layers
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),

        # Spatial Pyramid Pooling or similar global pooling
        GlobalAveragePooling2D(),

        # Fully-connected layers
        Dense(4096, kernel_initializer=HeNormal()),
        Dropout(0.5),
        PReLU(),
        Dense(4096, kernel_initializer=HeNormal()),
        Dropout(0.5),
        PReLU(),
        Dense(num_classes, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Example usage (assuming you have your image data loaded)
# model = modelA(input_shape=(224, 224, 3), num_classes=1000)
# model.fit(your_training_data, your_training_labels, epochs=your_epochs)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import PReLU
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.layers import GlobalAveragePooling2D  # Assuming Spatial Pyramid Pooling is similar

def make_model_B(input_shape=(32, 32, 3), num_classes=10):
    """
    Builds a VGG19 inspired model architecture modified according to the paper,
    with PReLU activation and adjustments in convolutional layers' configuration.

    Args:
        input_shape: The shape of the input images (default: (224, 224, 3) for ImageNet).
        num_classes: The number of output classes (default: 1000 for ImageNet).

    Returns:
        A compiled Keras Sequential model.
    """

    model = Sequential([
        # First conv layer with modified filter size and stride according to the paper.
        Conv2D(96, (7, 7), strides=(2, 2), padding='same', input_shape=input_shape, kernel_initializer=HeNormal()),
        PReLU(),

        # First pooling layer
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Second set of layers
        Conv2D(256, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        #
        Conv2D(256, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third set of layers
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        #
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third set of layers
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        #
        Conv2D(512, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),

        # Spatial Pyramid Pooling or similar global pooling
        GlobalAveragePooling2D(),

        # Fully-connected layers
        Dense(4096, kernel_initializer=HeNormal()),
        Dropout(0.5),
        PReLU(),
        Dense(4096, kernel_initializer=HeNormal()),
        Dropout(0.5),
        PReLU(),
        Dense(num_classes, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Example usage (assuming you have your image data loaded)
# model = modelA(input_shape=(224, 224, 3), num_classes=1000)
# model.fit(your_training_data, your_training_labels, epochs=your_epochs)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import PReLU
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.layers import GlobalAveragePooling2D  # Assuming Spatial Pyramid Pooling is similar

def make_model_C(input_shape=(32, 32, 3), num_classes=10):
    """
    Builds a VGG19 inspired model architecture modified according to the paper,
    with PReLU activation and adjustments in convolutional layers' configuration.

    Args:
        input_shape: The shape of the input images (default: (224, 224, 3) for ImageNet).
        num_classes: The number of output classes (default: 1000 for ImageNet).

    Returns:
        A compiled Keras Sequential model.
    """

    model = Sequential([
        # First conv layer with modified filter size and stride according to the paper.
        Conv2D(96, (7, 7), strides=(2, 2), padding='same', input_shape=input_shape, kernel_initializer=HeNormal()),
        PReLU(),

        # First pooling layer
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Second set of layers
        Conv2D(384, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(384, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(384, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(384, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(384, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        #
        Conv2D(384, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third set of layers
        Conv2D(768, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(768, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(768, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(768, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(768, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        #
        Conv2D(768, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third set of layers
        Conv2D(896, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(896, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(896, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(896, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        Conv2D(896, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),
        #
        Conv2D(896, (3, 3), padding='same', kernel_initializer=HeNormal()),
        PReLU(),

        # Spatial Pyramid Pooling or similar global pooling
        GlobalAveragePooling2D(),

        # Fully-connected layers
        Dense(4096, kernel_initializer=HeNormal()),
        Dropout(0.5),
        PReLU(),
        Dense(4096, kernel_initializer=HeNormal()),
        Dropout(0.5),
        PReLU(),
        Dense(num_classes, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Example usage (assuming you have your image data loaded)
# model = modelA(input_shape=(224, 224, 3), num_classes=1000)
# model.fit(your_training_data, your_training_labels, epochs=your_epochs)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def display_loss(history):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Model Loss')
  plt.ylabel('Loss')
  plt.xlabel('Number of Epochs')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()

def display_accuracy(history):
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('no of epochs')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

# %%
from tensorflow import random
from tensorflow.keras import initializers

class RandomUniformInitializer(initializers.Initializer):
  def __init__(self, seed=None):
    self.seed = seed

  def __call__(self, shape, dtype=None):
    if self.seed is not None:
      random.set_seed(self.seed)
    limit = 1.0 / np.sqrt(shape[-1])
    return random.uniform(shape, minval=-limit, maxval=limit, dtype=dtype)

# %%
#Based on the paper, page 250-251, part 2.3, we computed negative log_liklihood over 10 consecutive training pairs (x, y) and used to update parameters θ in that direction
batch_size = 128
epochs = 20

# %%
modelA = make_model_A()

historyA = modelA.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

lossA, accuracyA = modelA.evaluate(X_test, y_test)

display_accuracy(historyA)
display_loss(historyA)
# Out:
# Epoch 1/20
#  20/313 [>.............................] - ETA: 1:36:39 - loss: 3.7303 - accuracy: 0.0941
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-f942180d47c5> in <cell line: 3>()
#       1 modelA = make_model_A()
#       2
# ----> 3 historyA = modelA.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
#       4
#       5 lossA, accuracyA = modelA.evaluate(X_test, y_test)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
modelB = make_model_B()

historyB = modelB.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

lossB, accuracyB = modelB.evaluate(X_test, y_test)

display_accuracy(historyB)
display_loss(historyB)

# %%
modelC = make_model_C()

historyC = modelC.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

lossC, accuracyC = modelC.evaluate(X_test, y_test)

display_accuracy(historyC)
display_loss(historyC)

# %%
batch_size = 128
epochs = 150

# %%
# Flatten the images and normalize the pixel values
X_train = X_train.reshape(-1, 32* 32*3)
X_val = X_val.reshape(-1, 32* 32*3)
X_test = X_test.reshape(-1, 32* 32*3)

#Normalize the pixel values
# X_train = X_train / 255.0
# X_val = X_val / 255.0
# X_test = X_test / 255.0

# %%
import tensorflow

sigmoid_model_S = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 4, activation_func = 'sigmoid', initializer = RandomUniformInitializer())


def train_model(model):
  # Lists to store activation statistics for each epoch
  losses = []
  val_losses = []
  accuracies = []
  val_accuracies = []
  means_per_epoch = []
  stds_per_epoch = []
  percentiles_per_epoch = []

  # Training loop
  for epoch in range(epochs):
      # Create a data generator for the training set
      train_data_gen = tensorflow.data.Dataset.from_tensor_slices((X_train, y_train)).batch(batch_size)

      # Get the activations for each layer
      activations = []
      layer_outputs = []
      for layer in model.layers:
          if isinstance(layer, keras.layers.Dense):
              layer_outputs.append([])

      for inputs, targets in train_data_gen:
          layer_input = inputs
          for i, layer in enumerate(model.layers):
              if isinstance(layer, keras.layers.Dense):
                  output = layer(layer_input)
                  layer_outputs[i].append(output.numpy().flatten())
                  layer_input = output

      # Calculate the mean, standard deviation, and percentiles for each layer
      means = []
      stds = []
      percentiles = []
      for activations_layer in layer_outputs:
          activations_layer = np.concatenate(activations_layer)
          means.append(np.mean(activations_layer))
          stds.append(np.std(activations_layer))
          percentiles.append(np.percentile(activations_layer, 98))

      # Store the statistics for this epoch
      means_per_epoch.append(means)
      stds_per_epoch.append(stds)
      percentiles_per_epoch.append(percentiles)

      # Fit the model for this epoch
      print(f"Epoch: {epoch+1} / {epochs}")
      sigmoid_history_S = model.fit(X_train, y_train, batch_size=batch_size, epochs=1, validation_data=(X_val, y_val))

      losses.append(sigmoid_history_S.history['loss'])
      accuracies.append(sigmoid_history_S.history['accuracy'])
      val_losses.append(sigmoid_history_S.history['val_loss'])
      val_accuracies.append(sigmoid_history_S.history['val_accuracy'])
  return losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch

# Plot the results

# %%
losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch = train_model(sigmoid_model_S)
sigmoid_loss_G, sigmoid_accuracy_G = sigmoid_model_S.evaluate(X_test, y_test)
# Out:
# Epoch: 1 / 150
# 313/313 [==============================] - 4s 12ms/step - loss: 2.3207 - accuracy: 0.0994 - val_loss: 2.3031 - val_accuracy: 0.1023
# Epoch: 2 / 150
# 313/313 [==============================] - 4s 12ms/step - loss: 2.3031 - accuracy: 0.1019 - val_loss: 2.3037 - val_accuracy: 0.0933
# Epoch: 3 / 150
# 313/313 [==============================] - 3s 11ms/step - loss: 2.3032 - accuracy: 0.0993 - val_loss: 2.3030 - val_accuracy: 0.1015
# Epoch: 4 / 150
# 313/313 [==============================] - 5s 15ms/step - loss: 2.3032 - accuracy: 0.0963 - val_loss: 2.3032 - val_accuracy: 0.0979
# Epoch: 5 / 150
# 313/313 [==============================] - 4s 11ms/step - loss: 2.3030 - accuracy: 0.0994 - val_loss: 2.3049 - val_accuracy: 0.0933
# Epoch: 6 / 150
# 313/313 [==============================] - 4s 12ms/step - loss: 2.3031 - accuracy: 0.1013 - val_loss: 2.3034 - val_accuracy: 0.1017
# Epoch: 7 / 150
# 313/313 [==============================] - 4s 11ms/step - loss: 2.3030 - accuracy: 0.1002 - val_loss: 2.3049 - val_accuracy: 0.0996

# %%
import matplotlib.pyplot as plt

def plot_loss_acc(losses, val_losses, accuracies, val_accuracies):
  plt.figure(figsize=(12, 6))
  plt.subplot(1, 2, 1)
  plt.plot(range(1, epochs+1), losses, label='Training Loss')
  plt.plot(range(1, epochs+1), val_losses, label='Validation Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.title('Training Loss')
  plt.legend()

  plt.subplot(1, 2, 2)
  plt.plot(range(1, epochs+1), accuracies, label='Training Accuracy')
  plt.plot(range(1, epochs+1), val_accuracies, label='Validation Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.title('Training Accuracy')
  plt.legend()

plot_loss_acc(losses, val_losses, accuracies, val_accuracies)

# %%
import matplotlib.cm as cm  # Import colormap
def plot_activation_values(model, means_per_epoch, stds_per_epoch, percentiles_per_epoch):
  fig, ax1 = plt.subplots(figsize=(20, 6))
  num_dense_layers = sum(1 for layer in model.layers if isinstance(layer, keras.layers.Dense))

  colors = cm.rainbow(np.linspace(0, 1, num_dense_layers))
  skip_first = True

  for i, (layer, color) in enumerate(zip(model.layers, colors)):
    if(skip_first):
        skip_first = False
        continue
    if isinstance(layer, keras.layers.Dense):
        layer_means = [means_per_epoch[epoch][i] for epoch in range(epochs)]
        layer_stds = [stds_per_epoch[epoch][i] for epoch in range(epochs)]
        layer_percentiles = [percentiles_per_epoch[epoch][i] for epoch in range(epochs)]

        ax1.plot(range(1, epochs+1), layer_means, label=f'Mean (Layer {i+1})', color=color)
        ax1.errorbar(range(1, epochs+1), layer_means, yerr=layer_stds, fmt='.', color=color, label=f'Std Dev (Layer {i+1})')

  ax1.set_xlabel('Epoch')
  ax1.set_ylabel('Activation Value')
  ax1.set_title('Activation Value Statistics')
  ax1.legend()

  plt.show()

# %%
import matplotlib.cm as cm  # Import colormap
fig, ax1 = plt.subplots(figsize=(20, 6))

model = sigmoid_model_S

num_dense_layers = sum(1 for layer in model.layers if isinstance(layer, keras.layers.Dense))

colors = cm.rainbow(np.linspace(0, 1, num_dense_layers))
skip_first = True

for i, (layer, color) in enumerate(zip(model.layers, colors)):
    # if(skip_first):
    #   skip_first = False
    #   continue
    if isinstance(layer, keras.layers.Dense):
        layer_means = [means_per_epoch[epoch][i] for epoch in range(epochs)]
        layer_stds = [stds_per_epoch[epoch][i] for epoch in range(epochs)]
        layer_percentiles = [percentiles_per_epoch[epoch][i] for epoch in range(epochs)]

        ax1.plot(range(1, epochs+1), layer_means, label=f'Mean (Layer {i+1})', color=color)
        ax1.errorbar(range(1, epochs+1), layer_means, yerr=layer_stds, fmt='.', color=color, label=f'Std Dev (Layer {i+1})')
        ax1.plot(range(1, epochs+1), layer_percentiles, '^', color=color, label=f'98th Percentile (Layer {i+1})')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Activation Value')
ax1.set_title('Activation Value Statistics')
ax1.legend()

plt.show()

# %% [markdown]
# The bars representing the standard deviation for the first layer appear larger than the others because the activations in the first layer tend to have a larger variance compared to the subsequent layers.
#
# This is a common phenomenon in neural networks, where the activations in the earlier layers (closer to the input) tend to have a higher variability or spread, while the activations in the later layers become more stable and have a smaller variance.
#
# There are a few reasons why this happens:
#
# 1. **Input Distribution**: The activations in the first layer are directly influenced by the input data distribution, which can be quite diverse and have a large range of values, leading to higher variance in the activations.
#
# 2. **Weight Initialization**: The initial weights in the first layer are randomly initialized, which can introduce higher variability in the activations compared to later layers, where the weights have been optimized during training.
#
# 3. **Feature Extraction**: The early layers in a neural network are responsible for extracting low-level features from the input data, which can result in a wider range of activation values as the network learns to represent different patterns and features.
#
# 4. **Normalization**: Later layers in the network often benefit from the normalization or regularization techniques applied to the activations, such as batch normalization or dropout, which can reduce the variance and stabilize the activations.

# %%
plot_activation_values(sigmoid_model_S, means_per_epoch, stds_per_epoch, percentiles_per_epoch)

# %%
sigmoid_model_G = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 4, activation_func = 'sigmoid', initializer =  initializers.GlorotNormal())

losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch = train_model(sigmoid_model_G)
sigmoid_loss_G, sigmoid_accuracy_G = sigmoid_model_G.evaluate(X_test, y_test)
plot_loss_acc(losses, val_losses, accuracies, val_accuracies)
plot_activation_values(sigmoid_model_G, means_per_epoch, stds_per_epoch, percentiles_per_epoch)

# %%
tanh_model_S = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'tanh', initializer = RandomUniformInitializer())

losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch = train_model(tanh_model_S)
tanh_loss_S, tanh_accuracy_S = tanh_model_S.evaluate(X_test, y_test)
plot_loss_acc(losses, val_losses, accuracies, val_accuracies)
plot_activation_values(tanh_model_S, means_per_epoch, stds_per_epoch, percentiles_per_epoch)

# %%
tanh_model_G = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'tanh', initializer = initializers.GlorotNormal())

losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch = train_model(tanh_model_G)
tanh_loss_G, tanh_accuracy_G = tanh_model_G.evaluate(X_test, y_test)
plot_loss_acc(losses, val_losses, accuracies, val_accuracies)
plot_activation_values(tanh_model_G, means_per_epoch, stds_per_epoch, percentiles_per_epoch)

# %%
softsign_model_S = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'softsign', initializer = RandomUniformInitializer())

losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch = train_model(softsign_model_S)
softsign_loss_G, softsign_accuracy_G = softsign_model_S.evaluate(X_test, y_test)
plot_loss_acc(losses, val_losses, accuracies, val_accuracies)
plot_activation_values(softsign_model_S, means_per_epoch, stds_per_epoch, percentiles_per_epoch)

# %%
softsign_model_G = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'softsign', initializer = initializers.GlorotNormal())

losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch = train_model(softsign_model_G)
softsign_loss_G, softsign_accuracy_G = softsign_model_G.evaluate(X_test, y_test)
plot_loss_acc(losses, val_losses, accuracies, val_accuracies)
plot_activation_values(softsign_model_G, means_per_epoch, stds_per_epoch, percentiles_per_epoch)

# %%
relu_model_G = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'relu', initializer = initializers.GlorotNormal())

losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch = train_model(relu_model_G)
relu_loss_G, relu_accuracy_G = relu_model_G.evaluate(X_test, y_test)
plot_loss_acc(losses, val_losses, accuracies, val_accuracies)
plot_activation_values(relu_model_G, means_per_epoch, stds_per_epoch, percentiles_per_epoch)

# %%
def make_relu(alpha):  # Define a custom Leaky ReLU function with learnable alpha
  def activate(x):
    return keras.activations.relu(x, alpha=alpha)
  return activate

leaky_relu = make_relu(alpha=0.01)
prelu = make_relu(alpha=0.25)

# %%
relu_model_H = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'relu', initializer = initializers.he_normal())

losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch = train_model(relu_model_H)
relu_loss_H, relu_accuracy_H = relu_model_H.evaluate(X_test, y_test)
plot_loss_acc(losses, val_losses, accuracies, val_accuracies)
plot_activation_values(relu_model_H, means_per_epoch, stds_per_epoch, percentiles_per_epoch)

# %%
leaky_relu_model_H = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = leaky_relu, initializer = initializers.he_normal())

losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch = train_model(leaky_relu_model_H)
leaky_relu_loss_H, leaky_relu_accuracy_H = leaky_relu_model_H.evaluate(X_test, y_test)
plot_loss_acc(losses, val_losses, accuracies, val_accuracies)
plot_activation_values(leaky_relu_model_H, means_per_epoch, stds_per_epoch, percentiles_per_epoch)

# %%
prelu_model_H = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = prelu, initializer = initializers.he_normal())

losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch = train_model(prelu_model_H)
prelu_loss_H, prelu_accuracy_H = prelu_model_H.evaluate(X_test, y_test)
plot_loss_acc(losses, val_losses, accuracies, val_accuracies)
plot_activation_values(prelu_model_H, means_per_epoch, stds_per_epoch, percentiles_per_epoch)
