# %% [markdown]
# <a href="https://colab.research.google.com/github/Arko04/Colab/blob/main/HW3_P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="display:block;width:100%;margin:auto;" direction=rtl align=center><br><br>
#     <div  style="width:100%;margin:100;display:block;background-color:#fff0;"  display=block align=center>
#         <table style="border-style:hidden;border-collapse:collapse;">
#             <tr>
#                 <td  style="border: none!important;">
#         <img width=230 align=right src="https://i.ibb.co/yXKQmtZ/logo1.png" style="margin:0;" />
#                 </td>
#                 <td style="text-align:center;border: none!important;">
#                 <h1 align=center><font size=5 color="#045F5F"> <b>HomeWork3-Part1</b><br><br>AliMosReza</i></font></h1>
#                 </td>
#                 <td style="border: none!important;">
#         <img width=300 align=left  src="https://i.ibb.co/wLjqFkw/logo2.png" style="margin:0;" />
#                 </td>
#             </tr>
#         </table>

# %%
from google.colab import drive
drive.mount('/content/grive')
# Out:
# Mounted at /content/grive

# %%
from IPython.display import Image

# %%
Image(filename='/content/grive/MyDrive/HW3_P1/Slides/activation_function.jpeg', width=600,height=400)

# %%
Image(filename='/content/grive/MyDrive/HW3_P1/Slides/activation_functions.png', width=900,height=400)

# %%
import pandas as pd
import numpy as np

# %%
from tensorflow.keras.datasets import cifar10

# data = mnist.load_data()
data = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 4s 0us/step

# %% [markdown]
# source: https://www.analyticsvidhya.com/blog/2021/06/mnist-dataset-prediction-using-keras/

# %%
data
# Out:
# ((array([[[[ 59,  62,  63],
#            [ 43,  46,  45],
#            [ 50,  48,  43],
#            ...,
#            [158, 132, 108],
#            [152, 125, 102],
#            [148, 124, 103]],
#
#           [[ 16,  20,  20],
#            [  0,   0,   0],
#            [ 18,   8,   0],
#            ...,
#            [123,  88,  55],
#            [119,  83,  50],
#            [122,  87,  57]],
#
#           [[ 25,  24,  21],
#            [ 16,   7,   0],
#            [ 49,  27,   8],
#            ...,
#            [118,  84,  50],
#            [120,  84,  50],
#            [109,  73,  42]],
#
#           ...,
#
#           [[208, 170,  96],
#            [201, 153,  34],
#            [198, 161,  26],
#            ...,
#            [160, 133,  70],
#            [ 56,  31,   7],
#            [ 53,  34,  20]],
#
#           [[180, 139,  96],
#            [173, 123,  42],
#            [186, 144,  30],
#            ...,
#            [184, 148,  94],
#            [ 97,  62,  34],
# ...

# %%
type(data)
# Out:
# tuple

# %%
(X_train, y_train), (X_test, y_test) = data

print(X_train.shape, y_train.shape)
print(X_train[0].shape)


print(X_test.shape, y_test.shape)
print(X_test[0].shape)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (32, 32, 3)
# (10000, 32, 32, 3) (10000, 1)
# (32, 32, 3)

# %%
from sklearn.model_selection import train_test_split

# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=10000, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# ###usage of 'random_state = 42':

# %% [markdown]
# The random_state parameter in the train_test_split function in Scikit-learn is used to set the seed for the random number generator, ensuring that the train and test datasets are split in the same way every time the code is executed. The value of random_state is arbitrary, and 42 is commonly used as a convention, based on its significance in popular culture as the "Answer to the Ultimate Question of Life, the Universe, and Everything" in Douglas Adams' science fiction novel "The Hitchhiker's Guide to the Galaxy."
# Using a fixed value for random_state ensures that the results of the model are reproducible, allowing for more consistent and reliable comparisons between different models and experiments. It is recommended to set the random_state parameter in Scikit-learn algorithms, including train_test_split, to ensure that the results are reproducible and can be validated by others.

# %% [markdown]
# You can set the random_state parameter to any integer value. The specific value you choose for random_state does not affect the quality of the split; it only determines the random seed used for the splitting process.

# %% [markdown]
# The difference between setting the random seed to 42 or 12 or any other number is that the sequence of random numbers generated will be different, but the property of reproducibility will remain the same.

# %% [markdown]
# source: https://www.perplexity.ai/search/i-wanted-to-BK42_k8oQbidEldYO5Ul.Q

# %%
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (40000, 32, 32, 3) (40000, 1)
# (10000, 32, 32, 3) (10000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
# X_train_copy = X_train.copy()
# X_val_copy = X_val.copy()
# X_test_copy = X_test.copy()

# X_train_copy = X_train_copy / 255.0
# X_val_copy = X_val_copy / 255.0
# X_test_copy = X_test_copy / 255.0

# Flatten the images and normalize the pixel values
# X_train = X_train.reshape(-1, 28, 28)
# X_val = X_val.reshape(-1, 28, 28)
# X_test = X_test.reshape(-1, 28, 28)

#Normalize the pixel values
# X_train = X_train / 255.0
# X_val = X_val / 255.0
# X_test = X_test / 255.0

X_train = X_train.astype('float32') / 255
X_val = X_val.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# %%
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (40000, 32, 32, 3) (40000, 1)
# (10000, 32, 32, 3) (10000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
from tensorflow import keras
from tensorflow.keras import initializers

def build_model(input_shape, hidden_size, output_size, number_of_hidden_layers, activation_func, initializer):
  model = keras.Sequential()

  model.add(keras.Input(shape=input_shape))

  for _ in range(number_of_hidden_layers):
    model.add(keras.layers.Dense(hidden_size, activation=activation_func, kernel_initializer=initializer))

  model.add(keras.layers.Dense(output_size, activation="softmax"))

  model.compile(optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
  return model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.layers import Dropout


def vgg19_model(input_shape=(32, 32, 3), num_classes=10):
  """
  Builds a VGG19 model architecture from scratch.

  Args:
      input_shape: The shape of the input images (default: (224, 224, 3) for ImageNet).
      num_classes: The number of output classes (default: 1000 for ImageNet).

  Returns:
      A compiled Keras Sequential model representing the VGG19 architecture.
  """

  model = Sequential([
      # Block 1
      Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=input_shape),
      Conv2D(64, (3, 3), activation='relu', padding='same'),
      MaxPooling2D((2, 2), strides=(2, 2)),

      # Block 2
      Conv2D(128, (3, 3), activation='relu', padding='same'),
      Conv2D(128, (3, 3), activation='relu', padding='same'),
      MaxPooling2D((2, 2), strides=(2, 2)),

      # Block 3
      Conv2D(256, (3, 3), activation='relu', padding='same'),
      Conv2D(256, (3, 3), activation='relu', padding='same'),
      Conv2D(256, (3, 3), activation='relu', padding='same'),
      Conv2D(256, (3, 3), activation='relu', padding='same'),
      MaxPooling2D((2, 2), strides=(2, 2)),

      # Block 4
      Conv2D(512, (3, 3), activation='relu', padding='same'),
      Conv2D(512, (3, 3), activation='relu', padding='same'),
      Conv2D(512, (3, 3), activation='relu', padding='same'),
      Conv2D(512, (3, 3), activation='relu', padding='same'),
      MaxPooling2D((2, 2), strides=(2, 2)),

      # Block 5
      Conv2D(512, (3, 3), activation='relu', padding='same'),
      Conv2D(512, (3, 3), activation='relu', padding='same'),
      Conv2D(512, (3, 3), activation='relu', padding='same'),
      Conv2D(512, (3, 3), activation='relu', padding='same'),
      MaxPooling2D((2, 2), strides=(2, 2)),

      # Fully-connected layers
      Flatten(),
      Dense(4096, activation='relu'),
      Dropout(0.5),
      Dense(4096, activation='relu'),
      Dropout(0.5),
      Dense(num_classes, activation='softmax')
  ])

  # Compile the model (you can choose your optimizer and loss function)
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

  return model

# Example usage (assuming you have your image data loaded)
# model = vgg19_model(input_shape=(your_image_shape), num_classes=your_num_classes)
# model.fit(your_training_data, your_training_labels, epochs=your_epochs)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import PReLU

def modelAA(input_shape=(32, 32, 3), num_classes=10):
  """
  Builds a VGG19 model architecture from scratch.

  Args:
      input_shape: The shape of the input images (default: (224, 224, 3) for ImageNet).
      num_classes: The number of output classes (default: 1000 for ImageNet).

  Returns:
      A compiled Keras Sequential model representing the VGG19 architecture.
  """

  model = Sequential([
      # Block 1
      Conv2D(96, (7, 7), strides=(2, 2), padding='same'),
      PReLU(),
      # Block 2
      MaxPooling2D((2, 2), strides=(2, 2)),

      # Block 3
      Conv2D(256, (3, 3), padding='same'),
      PReLU(),
      Conv2D(256, (3, 3), padding='same'),
      PReLU(),
      Conv2D(256, (3, 3), padding='same'),
      PReLU(),
      Conv2D(256, (3, 3), padding='same'),
      PReLU(),
      Conv2D(256, (3, 3), padding='same'),
      PReLU(),
      MaxPooling2D((2, 2), strides=(2, 2)),

      # Block 4
      Conv2D(512, (3, 3), padding='same'),
      PReLU(),
      Conv2D(512, (3, 3), padding='same'),
      PReLU(),
      Conv2D(512, (3, 3), padding='same'),
      PReLU(),
      Conv2D(512, (3, 3), padding='same'),
      PReLU(),
      Conv2D(512, (3, 3), padding='same'),
      PReLU(),
      MaxPooling2D((2, 2), strides=(2, 2)),

      # Block 5
      Conv2D(512, (3, 3), padding='same'),
      PReLU(),
      Conv2D(512, (3, 3), padding='same'),
      PReLU(),
      Conv2D(512, (3, 3), padding='same'),
      PReLU(),
      Conv2D(512, (3, 3), padding='same'),
      PReLU(),
      Conv2D(512, (3, 3), padding='same'),
      PReLU(),
      MaxPooling2D((2, 2), strides=(2, 2)),

      # Fully-connected layers
      Flatten(),
      Dense(4096, kernel_initializer = initializers.he_normal()),
      Dropout(0.5),
      PReLU(),
      Dense(4096, kernel_initializer = initializers.he_normal()),
      Dropout(0.5),
      PReLU(),
      Dense(num_classes, activation='softmax')
  ])

  # Compile the model (you can choose your optimizer and loss function)
  model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

  return model

# Example usage (assuming you have your image data loaded)
# model = vgg19_model(input_shape=(your_image_shape), num_classes=your_num_classes)
# model.fit(your_training_data, your_training_labels, epochs=your_epochs)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def display_loss(history):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Model Loss')
  plt.ylabel('Loss')
  plt.xlabel('Number of Epochs')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()

def display_accuracy(history):
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('no of epochs')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

# %%
from tensorflow import random
from tensorflow.keras import initializers

class RandomUniformInitializer(initializers.Initializer):
  def __init__(self, seed=None):
    self.seed = seed

  def __call__(self, shape, dtype=None):
    if self.seed is not None:
      random.set_seed(self.seed)
    limit = 1.0 / np.sqrt(shape[-1])
    return random.uniform(shape, minval=-limit, maxval=limit, dtype=dtype)

# %%
#Based on the paper, page 250-251, part 2.3, we computed negative log_liklihood over 10 consecutive training pairs (x, y) and used to update parameters θ in that direction
batch_size = 128
epochs = 10 # the desired number of epochs is around 75

# %%
modelA = modelAA()

historyA = modelA.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

lossA, accuracyA = modelA.evaluate(X_test, y_test)
# Out:
# Epoch 1/10
# 313/313 [==============================] - 46s 97ms/step - loss: 2.3041 - accuracy: 0.0991 - val_loss: 2.3036 - val_accuracy: 0.1023
# Epoch 2/10
# 313/313 [==============================] - 28s 88ms/step - loss: 2.3039 - accuracy: 0.1005 - val_loss: 2.3027 - val_accuracy: 0.0996
# Epoch 3/10
# 313/313 [==============================] - 29s 92ms/step - loss: 2.3032 - accuracy: 0.1024 - val_loss: 2.3038 - val_accuracy: 0.0933
# Epoch 4/10
# 313/313 [==============================] - 29s 93ms/step - loss: 2.3031 - accuracy: 0.0970 - val_loss: 2.3031 - val_accuracy: 0.1017
# Epoch 5/10
# 313/313 [==============================] - 29s 92ms/step - loss: 2.3034 - accuracy: 0.0992 - val_loss: 2.3036 - val_accuracy: 0.0979
# Epoch 6/10
# 313/313 [==============================] - 28s 91ms/step - loss: 2.3046 - accuracy: 0.0989 - val_loss: 2.3039 - val_accuracy: 0.0933
# Epoch 7/10
# ...

# %%
batch_size = 128
epochs = 150

# %%
# Flatten the images and normalize the pixel values
X_train = X_train.reshape(-1, 32* 32*3)
X_val = X_val.reshape(-1, 32* 32*3)
X_test = X_test.reshape(-1, 32* 32*3)

#Normalize the pixel values
# X_train = X_train / 255.0
# X_val = X_val / 255.0
# X_test = X_test / 255.0


sigmoid_model_S = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 4, activation_func = 'sigmoid', initializer = RandomUniformInitializer())

sigmoid_history_S = sigmoid_model_S.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

sigmoid_loss_S, sigmoid_accuracy_S = sigmoid_model_S.evaluate(X_test, y_test)

display_loss(sigmoid_history_S)

display_accuracy(sigmoid_history_S)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 3s 7ms/step - loss: 2.3087 - accuracy: 0.1020 - val_loss: 2.3190 - val_accuracy: 0.1017
# Epoch 2/150
# 313/313 [==============================] - 2s 5ms/step - loss: 2.3086 - accuracy: 0.1004 - val_loss: 2.3063 - val_accuracy: 0.1030
# Epoch 3/150
# 313/313 [==============================] - 2s 5ms/step - loss: 2.3083 - accuracy: 0.0999 - val_loss: 2.3121 - val_accuracy: 0.1017
# Epoch 4/150
# 313/313 [==============================] - 2s 6ms/step - loss: 2.3079 - accuracy: 0.1020 - val_loss: 2.3070 - val_accuracy: 0.0933
# Epoch 5/150
# 313/313 [==============================] - 2s 6ms/step - loss: 2.3082 - accuracy: 0.1015 - val_loss: 2.3112 - val_accuracy: 0.0994
# Epoch 6/150
# 313/313 [==============================] - 2s 5ms/step - loss: 2.3085 - accuracy: 0.0996 - val_loss: 2.3069 - val_accuracy: 0.1015
# Epoch 7/150
# ...

# %%
import tensorflow

val_data_gen = tensorflow.data.Dataset.from_tensor_slices((X_val, y_val)).batch(batch_size)

# Get the activations for each layer
activations = []
layer_outputs = []
for layer in sigmoid_model_S.layers:
    if isinstance(layer, keras.layers.Dense):
        layer_outputs.append([])

for inputs, targets in val_data_gen:
    layer_input = inputs
    for i, layer in enumerate(sigmoid_model_S.layers):
        if isinstance(layer, keras.layers.Dense):
            output = layer(layer_input)
            layer_outputs[i].append(output.numpy().flatten())
            layer_input = output

    # Break after one batch (you can remove this if you want to use the entire validation set)
    break

# Calculate the mean and standard deviation for each layer
means = [np.mean(np.concatenate(layer_outputs[i])) for i in range(len(layer_outputs))]
stds = [np.std(np.concatenate(layer_outputs[i])) for i in range(len(layer_outputs))]

# Plot the mean and standard deviation
layer_indices = range(1, len(activations) + 1)
plt.figure(figsize=(10, 6))
plt.plot(layer_indices, means, label='Mean')
plt.plot(layer_indices, stds, label='Standard Deviation')
plt.xlabel('Layer')
plt.ylabel('Activation Value')
plt.title('Mean and Standard Deviation of Activation Values')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-25d7d176768c> in <cell line: 30>()
#      28 layer_indices = range(1, len(activations) + 1)
#      29 plt.figure(figsize=(10, 6))
# ---> 30 plt.plot(layer_indices, means, label='Mean')
#      31 plt.plot(layer_indices, stds, label='Standard Deviation')
#      32 plt.xlabel('Layer')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
sigmoid_model_G = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 4, activation_func = 'sigmoid', initializer =  initializers.GlorotNormal())

sigmoid_history_G = sigmoid_model_G.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

sigmoid_loss_G, sigmoid_accuracy_G = sigmoid_model_G.evaluate(X_test, y_test)

display_loss(sigmoid_history_G)

display_accuracy(sigmoid_history_G)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer GlorotNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Epoch 1/150
# 313/313 [==============================] - 3s 7ms/step - loss: 2.3114 - accuracy: 0.0997 - val_loss: 2.3097 - val_accuracy: 0.1017
# Epoch 2/150
# 313/313 [==============================] - 2s 5ms/step - loss: 2.3079 - accuracy: 0.1001 - val_loss: 2.3126 - val_accuracy: 0.0933
# Epoch 3/150
# 313/313 [==============================] - 2s 5ms/step - loss: 2.3081 - accuracy: 0.0999 - val_loss: 2.3174 - val_accuracy: 0.0933
# Epoch 4/150
# 313/313 [==============================] - 2s 5ms/step - loss: 2.3084 - accuracy: 0.1018 - val_loss: 2.3089 - val_accuracy: 0.0933
# ...

# %%
tanh_model_S = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'tanh', initializer = RandomUniformInitializer())

tanh_history_S = tanh_model_S.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

tanh_loss_S, tanh_accuracy_S = tanh_model_S.evaluate(X_test, y_test)

display_loss(tanh_history_S)

display_accuracy(tanh_history_S)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 3s 7ms/step - loss: 2.1746 - accuracy: 0.2290 - val_loss: 2.0318 - val_accuracy: 0.2902
# Epoch 2/150
# 313/313 [==============================] - 2s 5ms/step - loss: 1.9569 - accuracy: 0.3084 - val_loss: 1.9045 - val_accuracy: 0.3240
# Epoch 3/150
# 313/313 [==============================] - 2s 5ms/step - loss: 1.8737 - accuracy: 0.3387 - val_loss: 1.8805 - val_accuracy: 0.3382
# Epoch 4/150
# 313/313 [==============================] - 2s 6ms/step - loss: 1.8322 - accuracy: 0.3542 - val_loss: 1.8317 - val_accuracy: 0.3548
# Epoch 5/150
# 313/313 [==============================] - 2s 6ms/step - loss: 1.8022 - accuracy: 0.3641 - val_loss: 1.8076 - val_accuracy: 0.3560
# Epoch 6/150
# 313/313 [==============================] - 2s 6ms/step - loss: 1.7787 - accuracy: 0.3726 - val_loss: 1.7648 - val_accuracy: 0.3781
# Epoch 7/150
# ...

# %%
tanh_model_G = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'tanh', initializer = initializers.GlorotNormal())

tanh_history_G = tanh_model_G.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

tanh_loss_G, tanh_accuracy_G = tanh_model_G.evaluate(X_test, y_test)

display_loss(tanh_history_G)

display_accuracy(tanh_history_G)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 3s 7ms/step - loss: 1.9319 - accuracy: 0.3083 - val_loss: 1.8582 - val_accuracy: 0.3338
# Epoch 2/150
# 313/313 [==============================] - 2s 6ms/step - loss: 1.7989 - accuracy: 0.3657 - val_loss: 1.8212 - val_accuracy: 0.3474
# Epoch 3/150
# 313/313 [==============================] - 2s 6ms/step - loss: 1.7494 - accuracy: 0.3831 - val_loss: 1.7790 - val_accuracy: 0.3815
# Epoch 4/150
# 313/313 [==============================] - 2s 7ms/step - loss: 1.7119 - accuracy: 0.3982 - val_loss: 1.7980 - val_accuracy: 0.3613
# Epoch 5/150
# 313/313 [==============================] - 2s 6ms/step - loss: 1.6881 - accuracy: 0.4045 - val_loss: 1.7779 - val_accuracy: 0.3608
# Epoch 6/150
# 313/313 [==============================] - 2s 6ms/step - loss: 1.6440 - accuracy: 0.4190 - val_loss: 1.6518 - val_accuracy: 0.4096
# Epoch 7/150
# ...

# %%
softsign_model_S = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'softsign', initializer = RandomUniformInitializer())

softsign_history_S = softsign_model_S.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

softsign_loss_S, softsign_accuracy_S = softsign_model_S.evaluate(X_test, y_test)

display_loss(softsign_history_S)

display_accuracy(softsign_history_S)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 3s 7ms/step - loss: 2.2657 - accuracy: 0.1940 - val_loss: 2.2012 - val_accuracy: 0.2608
# Epoch 2/150
# 313/313 [==============================] - 2s 6ms/step - loss: 2.1072 - accuracy: 0.2716 - val_loss: 2.0370 - val_accuracy: 0.2794
# Epoch 3/150
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9906 - accuracy: 0.2905 - val_loss: 1.9741 - val_accuracy: 0.2886
# Epoch 4/150
# 313/313 [==============================] - 2s 6ms/step - loss: 1.9223 - accuracy: 0.3127 - val_loss: 1.8948 - val_accuracy: 0.3187
# Epoch 5/150
# 313/313 [==============================] - 2s 5ms/step - loss: 1.8818 - accuracy: 0.3289 - val_loss: 1.8625 - val_accuracy: 0.3307
# Epoch 6/150
# 313/313 [==============================] - 2s 5ms/step - loss: 1.8529 - accuracy: 0.3404 - val_loss: 1.8416 - val_accuracy: 0.3387
# Epoch 7/150
# ...

# %%
softsign_model_G = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'softsign', initializer = initializers.GlorotNormal())

softsign_history_G = softsign_model_G.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

softsign_loss_G, softsign_accuracy_G = softsign_model_G.evaluate(X_test, y_test)

display_loss(softsign_history_G)

display_accuracy(softsign_history_G)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 3s 8ms/step - loss: 2.0518 - accuracy: 0.2855 - val_loss: 1.9032 - val_accuracy: 0.3339
# Epoch 2/150
# 313/313 [==============================] - 2s 7ms/step - loss: 1.8515 - accuracy: 0.3520 - val_loss: 1.8432 - val_accuracy: 0.3362
# Epoch 3/150
# 313/313 [==============================] - 2s 5ms/step - loss: 1.7830 - accuracy: 0.3740 - val_loss: 1.7562 - val_accuracy: 0.3779
# Epoch 4/150
# 313/313 [==============================] - 2s 6ms/step - loss: 1.7452 - accuracy: 0.3871 - val_loss: 1.7427 - val_accuracy: 0.3761
# Epoch 5/150
# 313/313 [==============================] - 2s 6ms/step - loss: 1.7170 - accuracy: 0.3970 - val_loss: 1.7185 - val_accuracy: 0.3958
# Epoch 6/150
# 313/313 [==============================] - 2s 6ms/step - loss: 1.6917 - accuracy: 0.4079 - val_loss: 1.7084 - val_accuracy: 0.3939
# Epoch 7/150
# ...

# %%
relu_model_G = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'relu', initializer = initializers.GlorotNormal())

relu_history_G = relu_model_G.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

relu_loss_G, relu_accuracy_G = relu_model_G.evaluate(X_test, y_test)

display_loss(relu_history_G)

display_accuracy(relu_history_G)

# %%
def make_relu(alpha):  # Define a custom Leaky ReLU function with learnable alpha
  def activate(x):
    return keras.activations.relu(x, alpha=alpha)
  return activate

leaky_relu = make_relu(alpha=0.01)
prelu = make_relu(alpha=0.25)

# %%
relu_model_H = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'relu', initializer = initializers.he_normal())

relu_history_H = relu_model_H.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

relu_loss_H, relu_accuracy_H = relu_model_H.evaluate(X_test, y_test)

display_loss(relu_history_H)

display_accuracy(relu_history_H)

# %%
leaky_relu_model_H = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = 'leaky_rel', initializer = initializers.he_normal())

leaky_relu_history_H = leaky_relu_model_H.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

leaky_relu_loss_H, leaky_relu_accuracy_H = leaky_relu_model_H.evaluate(X_test, y_test)

display_loss(leaky_relu_history_H)

display_accuracy(leaky_relu_history_H)

# %%
prelu_model_H = build_model(input_shape = (32*32*3,), hidden_size = 1000, output_size = 10, number_of_hidden_layers = 5, activation_func = PReLU(), initializer = initializers.he_normal())

prelu_history_H = prelu_model_H.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

prelu_loss_H, prelu_accuracy_H = prelu_model_H.evaluate(X_test, y_test)

display_loss(prelu_history_H)

display_accuracy(prelu_history_H)
