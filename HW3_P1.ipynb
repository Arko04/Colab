# %% [markdown]
# <a href="https://colab.research.google.com/github/Arko04/Colab/blob/main/HW3_P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="display:block;width:100%;margin:auto;" direction=rtl align=center><br><br>
#     <div  style="width:100%;margin:100;display:block;background-color:#fff0;"  display=block align=center>
#         <table style="border-style:hidden;border-collapse:collapse;">
#             <tr>
#                 <td  style="border: none!important;">
#         <img width=230 align=right src="https://i.ibb.co/yXKQmtZ/logo1.png" style="margin:0;" />
#                 </td>
#                 <td style="text-align:center;border: none!important;">
#                 <h1 align=center><font size=5 color="#045F5F"> <b>HomeWork3-Part1</b><br><br>Alireza Karimi<br>810101492<br><br>
#                 Mostafa Kermaninia<br>810101575<br><br>Ali Dehghan<br>810101423<br></i></font></h1>
#                 </td>
#                 <td style="border: none!important;">
#         <img width=300 align=left  src="https://i.ibb.co/wLjqFkw/logo2.png" style="margin:0;" />
#                 </td>
#             </tr>
#         </table>

# %% [markdown]
# ## **$I.$ Xavier Glorot and Yoshua Bengio's initialization scheme**

# %% [markdown]
# For this section of the homework, we are going to compare different activation functions mentioned in the paper 1 which are sigmoid and tanh and softsign and in the paper 2 which are relu and leakyrelu and prelu.
#
# we also want to talk about different initialization methods discussed in the papers like standard iniitialization and normalized initialization(known for glorot uniform) and also the one that Kaiming He introduced in the second paper.
#
# We also want to talk about which initialization method is good for DNN and which one is good for shallower models.

# %% [markdown]
# ### **In paper1** we use **Soft-sign, sigmoid and hyperbolic tangent** activation functions:

# %% [markdown]
# ### **Sigmoid function (Logistic function):**
# $$ f(x) = \frac{1}{1 + e^{-x}}$$
# $$$$
# ### **Hyperbolic tangent (tanh) function:**
# $$ f(x) = \tanh(x) = \frac{e^{x} - e^{-x}}{e^{x} + e^{-x}} $$
# $$ $$
#
# ### **Softsign function:**
# $$ f(x) = \frac{x}{1 + |x|} $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the sigmoid function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Define the hyperbolic tangent function (tanh)
def tanh(x):
    return np.tanh(x)

# Define the softsign function
def softsign(x):
    return x / (1 + np.abs(x))

# Generate x values
x = np.linspace(-10, 10, 100)

# Calculate y values using the sigmoid, tanh, and softsign functions
y_sigmoid = sigmoid(x)
y_tanh = tanh(x)
y_softsign = softsign(x)

# Plot all three functions
plt.figure(figsize=(8, 6))
plt.plot(x, y_sigmoid, label='Sigmoid Function', color='blue')
plt.plot(x, y_tanh, label='Hyperbolic Tangent (tanh)', color='red', linestyle='--')
plt.plot(x, y_softsign, label='Softsign Function', color='green', linestyle=':')
plt.title('Plot of Sigmoid, Tanh, and Softsign Functions')
plt.xlabel('x')
plt.ylabel('Function Value')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# We initialized the biases to be 0 and the weights $W_{ij}$ at each layer with the below formula:
# $$ W_{ij} \sim U[(-\frac {\sqrt{6}}{\sqrt{n_{j}+n_{j+1}}}),(\frac {\sqrt{6}}{\sqrt{n_{j}+n_{j+1}}})]$$
#
# * $U[−a, a]$ is the uniform distribution in the interval $(−a, a)$
# * $n_{j}$ is the number of units (neurons) of the previous layer and $n_{j+1}$ is the number of units in the current layer
# * $W_{i,j}$ is every weight of each layer

# %% [markdown]
# ### **In paper2** we use **ReLU, Leaky ReLU and PReLU** activation functions:

# %% [markdown]
# ### **ReLU (Rectified Linear Unit) function:**
# $$f(x) = \max(0, x) \\
# $$
#
# ### **PReLU (Parametric ReLU) function:**
# $$ f(x) = \begin{cases}
#  x & \text{if } x > 0 \\
#  ax & \text{if } x \leq 0
#  \end{cases}
#  $$
#  $$ $$
#
# ### **Leaky ReLU function:**
# $$ f(x) = \begin{cases}
#  x & \text{if } x > 0 \\
#  ax & \text{if } x \leq 0
#  \end{cases}$$

# %%
# Define ReLU function
def relu(x):
    return np.maximum(0, x)

# Define PReLU function with parameter 'a'
def prelu(x, a):
    return np.where(x > 0, x, a * x)

# Define Leaky ReLU function with parameter 'a'
def leaky_relu(x, a):
    return np.where(x > 0, x, a * x)

# Generate input values
x = np.linspace(-10, 10, 100)

# Generate output values for each function
y_relu = relu(x)
y_prelu = prelu(x, 0.25)  # Assuming parameter 'a' as 0.1 for PReLU
y_leaky_relu = leaky_relu(x, 0.01)  # Assuming parameter 'a' as 0.01 for Leaky ReLU

# Plot ReLU, PReLU, and Leaky ReLU
plt.figure(figsize=(8, 6))
plt.plot(x, y_relu, label='ReLU', color='blue')
plt.plot(x, y_prelu, label='PReLU (a=0.25)', color='red', linestyle='--')
plt.plot(x, y_leaky_relu, label='Leaky ReLU (a=0.01)', color='green', linestyle='-.')
plt.title('Plot of ReLU, PReLU, and Leaky ReLU Functions')
plt.xlabel('x')
plt.ylabel('Output')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# And here is architectures of large models in part2's initialization scheme:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * all biases are initialized at 0
# * All $W_{i,j}$ are mutually independant and have a random distribution symmetrical around $0$ (e.g. $W_{i,j} \sim U(-k, k)$ or $W_{i,j} \sim \mathcal{N}(0, \sigma)$ and the distribution is the identical within weights in the same layer of our neural network

# %%
from IPython.display import Image

# %%
from google.colab import drive
drive.mount('/content/grive')
# Out:
# Mounted at /content/grive

# %%
import pandas as pd
import numpy as np

# %%
from tensorflow.keras.datasets import cifar10

data = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 3s 0us/step

# %% [markdown]
# ### **Why we use cifar10?**
# The CIFAR-10 dataset (Canadian Institute for Advanced Research, 10 classes) is a subset of the Tiny Images dataset and consists of 60000 32x32 color images. The images are labelled with one of 10 mutually exclusive classes: airplane, automobile (but not truck or pickup truck), bird, cat, deer, dog, frog, horse, ship, and truck (but not pickup truck). There are 6000 images per class with 5000 training and 1000 testing images per class.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# source: https://paperswithcode.com/dataset/cifar-10

# %%
data
# Out:
# ((array([[[[ 59,  62,  63],
#            [ 43,  46,  45],
#            [ 50,  48,  43],
#            ...,
#            [158, 132, 108],
#            [152, 125, 102],
#            [148, 124, 103]],
#
#           [[ 16,  20,  20],
#            [  0,   0,   0],
#            [ 18,   8,   0],
#            ...,
#            [123,  88,  55],
#            [119,  83,  50],
#            [122,  87,  57]],
#
#           [[ 25,  24,  21],
#            [ 16,   7,   0],
#            [ 49,  27,   8],
#            ...,
#            [118,  84,  50],
#            [120,  84,  50],
#            [109,  73,  42]],
#
#           ...,
#
#           [[208, 170,  96],
#            [201, 153,  34],
#            [198, 161,  26],
#            ...,
#            [160, 133,  70],
#            [ 56,  31,   7],
#            [ 53,  34,  20]],
#
#           [[180, 139,  96],
#            [173, 123,  42],
#            [186, 144,  30],
#            ...,
#            [184, 148,  94],
#            [ 97,  62,  34],
# ...

# %%
(X_train, y_train), (X_test, y_test)  = data

# %%
print(X_train.shape, y_train.shape)
print(X_train[0].shape)


print(X_test.shape, y_test.shape)
print(X_test[0].shape)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (32, 32, 3)
# (10000, 32, 32, 3) (10000, 1)
# (32, 32, 3)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# ###usage of 'random_state = 42':

# %% [markdown]
# * The random_state parameter in the train_test_split function in Scikit-learn is used to set the seed for the random number generator, ensuring that the train and test datasets are split in the same way every time the code is executed. The value of random_state is arbitrary, and 42 is commonly used as a convention, based on its significance in popular culture as the "Answer to the Ultimate Question of Life, the Universe, and Everything" in Douglas Adams' science fiction novel "The Hitchhiker's Guide to the Galaxy."
# Using a fixed value for random_state ensures that the results of the model are reproducible, allowing for more consistent and reliable comparisons between different models and experiments. It is recommended to set the random_state parameter in Scikit-learn algorithms, including train_test_split, to ensure that the results are reproducible and can be validated by others.
#
# * You can set the random_state parameter to any integer value. The specific value you choose for random_state does not affect the quality of the split; it only determines the random seed used for the splitting process.
#
# * The difference between setting the random seed to 42 or 12 or any other number is that the sequence of random numbers generated will be different, but the property of reproducibility will remain the same.

# %%
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (40000, 32, 32, 3) (40000, 1)
# (10000, 32, 32, 3) (10000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %% [markdown]
# source: https://www.perplexity.ai/search/i-wanted-to-BK42_k8oQbidEldYO5Ul.Q

# %%
X_train_copy = X_train.copy()
X_val_copy = X_val.copy()
X_test_copy = X_test.copy()

# %%
from tensorflow import keras
from keras import initializers

def build_model(input_shape, hidden_size, output_size, number_of_hidden_layers, activation_func, initializer):
  model = keras.Sequential()

  model.add(keras.Input(shape=input_shape))

  for _ in range(number_of_hidden_layers):
    model.add(keras.layers.Dense(hidden_size, activation=activation_func, kernel_initializer=initializer))
    model.add(keras.layers.Dropout(0.5))

  model.add(keras.layers.Dense(output_size, activation="softmax"))

  model.compile(optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
  return model

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def display_loss(history):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Model Loss')
  plt.ylabel('Loss')
  plt.xlabel('Number of Epochs')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()

def display_accuracy(history):
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('no of epochs')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

# %% [markdown]
# And based on the paper, when we use sigmoid, we build 4 hidden layers and for tanh and soft-sign we use 5 hidden layers as it said in paper.
#
# the number of units in each layer is 1000 and the number of classes is 10.
#
# According to paper 1, it finds the best learning rate for each activcation function by doing hyperparameter optimization
# after a large number of updates (5 million). As it is not possible for us to do so, we use the default learning rate for them.

# %%
batch_size = 128
epochs = 150

# %%
# Flatten the images and normalize the pixel values
X_train = X_train.reshape(-1, 32* 32*3)
X_val = X_val.reshape(-1, 32* 32*3)
X_test = X_test.reshape(-1, 32* 32*3)

#Normalize the pixel values

X_train = X_train / 255.0
X_val = X_val / 255.0
X_test = X_test / 255.0

# %% [markdown]
# # **SIGMOID**
# ## **MODEL1**

# %%
sigmoid_model_S = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 4, activation_func = 'sigmoid', initializer = "random_uniform")
sigmoid_history_S = sigmoid_model_S.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
sigmoid_loss_S, sigmoid_accuracy_S = sigmoid_model_S.evaluate(X_test, y_test)
display_loss(sigmoid_history_S)
display_accuracy(sigmoid_history_S)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 5s 14ms/step - loss: 2.4868 - accuracy: 0.0979 - val_loss: 2.3028 - val_accuracy: 0.1040
# Epoch 2/150
# 313/313 [==============================] - 3s 9ms/step - loss: 2.4392 - accuracy: 0.1018 - val_loss: 2.3035 - val_accuracy: 0.1017
# Epoch 3/150
# 313/313 [==============================] - 3s 8ms/step - loss: 2.4078 - accuracy: 0.1009 - val_loss: 2.3032 - val_accuracy: 0.1015
# Epoch 4/150
# 313/313 [==============================] - 3s 9ms/step - loss: 2.3862 - accuracy: 0.0986 - val_loss: 2.3033 - val_accuracy: 0.0933
# Epoch 5/150
# 313/313 [==============================] - 4s 12ms/step - loss: 2.3699 - accuracy: 0.1034 - val_loss: 2.3027 - val_accuracy: 0.1015
# Epoch 6/150
# 313/313 [==============================] - 3s 11ms/step - loss: 2.3626 - accuracy: 0.1005 - val_loss: 2.3032 - val_accuracy: 0.0933
# Epoch 7/150
# ...

# %%
sigmoid_model_G = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 4, activation_func = 'sigmoid', initializer = "glorot_uniform")
sigmoid_history_G = sigmoid_model_G.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
sigmoid_loss_G, sigmoid_accuracy_G = sigmoid_model_G.evaluate(X_test, y_test)
display_loss(sigmoid_history_G)
display_accuracy(sigmoid_history_G)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 4s 11ms/step - loss: 2.5074 - accuracy: 0.1008 - val_loss: 2.3031 - val_accuracy: 0.0964
# Epoch 2/150
# 313/313 [==============================] - 3s 9ms/step - loss: 2.4501 - accuracy: 0.0995 - val_loss: 2.3036 - val_accuracy: 0.0933
# Epoch 3/150
# 313/313 [==============================] - 4s 14ms/step - loss: 2.4187 - accuracy: 0.1009 - val_loss: 2.3028 - val_accuracy: 0.0933
# Epoch 4/150
# 313/313 [==============================] - 3s 9ms/step - loss: 2.3913 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0982
# Epoch 5/150
# 313/313 [==============================] - 3s 9ms/step - loss: 2.3788 - accuracy: 0.0991 - val_loss: 2.3030 - val_accuracy: 0.0996
# Epoch 6/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.3640 - accuracy: 0.0990 - val_loss: 2.3028 - val_accuracy: 0.0933
# Epoch 7/150
# ...

# %%
sigmoid_model_H = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 4, activation_func = 'sigmoid', initializer = "he_normal")
sigmoid_history_H = sigmoid_model_H.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
sigmoid_loss_H, sigmoid_accuracy_H = sigmoid_model_H.evaluate(X_test, y_test)
display_loss(sigmoid_history_H)
display_accuracy(sigmoid_history_H)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 6s 16ms/step - loss: 2.5275 - accuracy: 0.1013 - val_loss: 2.3033 - val_accuracy: 0.1020
# Epoch 2/150
# 313/313 [==============================] - 6s 19ms/step - loss: 2.4621 - accuracy: 0.0988 - val_loss: 2.3027 - val_accuracy: 0.0996
# Epoch 3/150
# 313/313 [==============================] - 6s 19ms/step - loss: 2.4267 - accuracy: 0.0992 - val_loss: 2.3024 - val_accuracy: 0.0973
# Epoch 4/150
# 313/313 [==============================] - 9s 27ms/step - loss: 2.4001 - accuracy: 0.1001 - val_loss: 2.3025 - val_accuracy: 0.1023
# Epoch 5/150
# 313/313 [==============================] - 7s 21ms/step - loss: 2.3788 - accuracy: 0.1034 - val_loss: 2.3024 - val_accuracy: 0.0994
# Epoch 6/150
# 313/313 [==============================] - 7s 22ms/step - loss: 2.3692 - accuracy: 0.0988 - val_loss: 2.3021 - val_accuracy: 0.0994
# Epoch 7/150
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for losses and accuracies
losses = [sigmoid_loss_S, sigmoid_loss_G, sigmoid_loss_H]
accuracies = [sigmoid_accuracy_S, sigmoid_accuracy_G, sigmoid_accuracy_H]

# Create two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot for losses
ax1.bar(['Experiment 1', 'Experiment 2', 'Experiment 3'], losses, color='blue')
ax1.set_title('Losses Comparison')
ax1.set_ylabel('Loss')
ax1.set_xlabel('Experiment')

# Plot for accuracies
ax2.bar(['Experiment 1', 'Experiment 2', 'Experiment 3'], accuracies, color='green')
ax2.set_title('Accuracies Comparison')
ax2.set_ylabel('Accuracy')
ax2.set_xlabel('Experiment')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **TANH**
# ## **MODEL1**

# %%
tanh_model_S = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'tanh', initializer = 'random_uniform')
tanh_history_S = tanh_model_S.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
tanh_loss_S, tanh_accuracy_S = tanh_model_S.evaluate(X_test, y_test)
display_loss(tanh_history_S)
display_accuracy(tanh_history_S)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 5s 13ms/step - loss: 2.3029 - accuracy: 0.1001 - val_loss: 2.3024 - val_accuracy: 0.1084
# Epoch 2/150
# 313/313 [==============================] - 4s 14ms/step - loss: 2.3023 - accuracy: 0.1050 - val_loss: 2.3017 - val_accuracy: 0.1248
# Epoch 3/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.3016 - accuracy: 0.1094 - val_loss: 2.3009 - val_accuracy: 0.1512
# Epoch 4/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.3007 - accuracy: 0.1160 - val_loss: 2.2995 - val_accuracy: 0.1687
# Epoch 5/150
# 313/313 [==============================] - 3s 11ms/step - loss: 2.2988 - accuracy: 0.1272 - val_loss: 2.2969 - val_accuracy: 0.1877
# Epoch 6/150
# 313/313 [==============================] - 4s 14ms/step - loss: 2.2947 - accuracy: 0.1417 - val_loss: 2.2899 - val_accuracy: 0.1935
# Epoch 7/150
# ...

# %%
tanh_model_G = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'tanh', initializer = "glorot_uniform")
tanh_history_G = tanh_model_G.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
tanh_loss_G, tanh_accuracy_G = tanh_model_G.evaluate(X_test, y_test)
display_loss(tanh_history_G)
display_accuracy(tanh_history_G)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer GlorotNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Epoch 1/150
# 313/313 [==============================] - 4s 11ms/step - loss: 2.6153 - accuracy: 0.1094 - val_loss: 2.1374 - val_accuracy: 0.2152
# Epoch 2/150
# 313/313 [==============================] - 4s 14ms/step - loss: 2.3725 - accuracy: 0.1467 - val_loss: 2.0339 - val_accuracy: 0.2434
# Epoch 3/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.2521 - accuracy: 0.1720 - val_loss: 1.9999 - val_accuracy: 0.2741
# Epoch 4/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.1917 - accuracy: 0.1850 - val_loss: 2.0032 - val_accuracy: 0.2682
# ...

# %%
tanh_model_H = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'tanh', initializer = "he_normal")
tanh_history_H = tanh_model_H.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
tanh_loss_H, tanh_accuracy_H = tanh_model_H.evaluate(X_test, y_test)
display_loss(tanh_history_H)
display_accuracy(tanh_history_H)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Epoch 1/150
# 313/313 [==============================] - 4s 11ms/step - loss: 2.8692 - accuracy: 0.1007 - val_loss: 2.2704 - val_accuracy: 0.1180
# Epoch 2/150
# 313/313 [==============================] - 4s 14ms/step - loss: 2.5935 - accuracy: 0.1083 - val_loss: 2.1970 - val_accuracy: 0.1844
# Epoch 3/150
# 313/313 [==============================] - 3s 9ms/step - loss: 2.4300 - accuracy: 0.1216 - val_loss: 2.1508 - val_accuracy: 0.2036
# Epoch 4/150
# 313/313 [==============================] - 3s 9ms/step - loss: 2.3130 - accuracy: 0.1414 - val_loss: 2.1497 - val_accuracy: 0.2172
# Epoch 5/150
# ...

# %% [markdown]
# # **SOFTSIGN**
# ## **MODEL1**

# %%
softsign_model_S = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'softsign', initializer = "random_uniform")
softsign_history_S = softsign_model_S.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
softsign_loss_S, softsign_accuracy_S = softsign_model_S.evaluate(X_test, y_test)
display_loss(softsign_history_S)
display_accuracy(softsign_history_S)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 4s 12ms/step - loss: 2.3027 - accuracy: 0.1000 - val_loss: 2.3027 - val_accuracy: 0.0974
# Epoch 2/150
# 313/313 [==============================] - 5s 15ms/step - loss: 2.3026 - accuracy: 0.1024 - val_loss: 2.3025 - val_accuracy: 0.1079
# Epoch 3/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.3024 - accuracy: 0.1056 - val_loss: 2.3023 - val_accuracy: 0.1017
# Epoch 4/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.3022 - accuracy: 0.1045 - val_loss: 2.3020 - val_accuracy: 0.0934
# Epoch 5/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.3019 - accuracy: 0.1051 - val_loss: 2.3017 - val_accuracy: 0.1043
# Epoch 6/150
# 313/313 [==============================] - 5s 16ms/step - loss: 2.3015 - accuracy: 0.1091 - val_loss: 2.3012 - val_accuracy: 0.0933
# Epoch 7/150
# ...

# %%
softsign_model_G = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'softsign', initializer = "glorot_uniform")
softsign_history_G = softsign_model_G.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
softsign_loss_G, softsign_accuracy_G = softsign_model_G.evaluate(X_test, y_test)
display_loss(softsign_history_G)
display_accuracy(softsign_history_G)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 5s 15ms/step - loss: 2.3634 - accuracy: 0.1077 - val_loss: 2.2230 - val_accuracy: 0.1823
# Epoch 2/150
# 313/313 [==============================] - 6s 18ms/step - loss: 2.2874 - accuracy: 0.1380 - val_loss: 2.1163 - val_accuracy: 0.2415
# Epoch 3/150
# 313/313 [==============================] - 5s 17ms/step - loss: 2.2058 - accuracy: 0.1700 - val_loss: 2.0409 - val_accuracy: 0.2357
# Epoch 4/150
# 313/313 [==============================] - 7s 24ms/step - loss: 2.1451 - accuracy: 0.1893 - val_loss: 2.0043 - val_accuracy: 0.2458
# Epoch 5/150
# 313/313 [==============================] - 6s 18ms/step - loss: 2.1143 - accuracy: 0.2001 - val_loss: 1.9934 - val_accuracy: 0.2630
# Epoch 6/150
# 313/313 [==============================] - 5s 15ms/step - loss: 2.0888 - accuracy: 0.2095 - val_loss: 1.9545 - val_accuracy: 0.2821
# Epoch 7/150
# ...

# %%
softsign_model_H = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'softsign', initializer = "he_normal")
softsign_history_H = softsign_model_H.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
softsign_loss_H, softsign_accuracy_H = softsign_model_H.evaluate(X_test, y_test)
display_loss(softsign_history_H)
display_accuracy(softsign_history_H)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 4s 11ms/step - loss: 2.4579 - accuracy: 0.1060 - val_loss: 2.2122 - val_accuracy: 0.2170
# Epoch 2/150
# 313/313 [==============================] - 4s 12ms/step - loss: 2.3708 - accuracy: 0.1274 - val_loss: 2.0979 - val_accuracy: 0.2453
# Epoch 3/150
# 313/313 [==============================] - 4s 11ms/step - loss: 2.2804 - accuracy: 0.1531 - val_loss: 2.0303 - val_accuracy: 0.2466
# Epoch 4/150
# 313/313 [==============================] - 3s 9ms/step - loss: 2.2087 - accuracy: 0.1753 - val_loss: 2.0004 - val_accuracy: 0.2654
# Epoch 5/150
# 313/313 [==============================] - 3s 9ms/step - loss: 2.1635 - accuracy: 0.1887 - val_loss: 1.9807 - val_accuracy: 0.2786
# Epoch 6/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.1293 - accuracy: 0.1987 - val_loss: 1.9703 - val_accuracy: 0.2900
# Epoch 7/150
# ...

# %% [markdown]
# # **RELU**
# ## **MODEL1**

# %%
relu_model_S = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'relu', initializer = "random_uniform")
relu_history_S = relu_model_S.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
relu_loss_S, softsign_accuracy_S = relu_model_S.evaluate(X_test, y_test)
display_loss(relu_history_S)
display_accuracy(relu_history_S)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 5s 12ms/step - loss: 2.3026 - accuracy: 0.0994 - val_loss: 2.3026 - val_accuracy: 0.0936
# Epoch 2/150
# 313/313 [==============================] - 4s 11ms/step - loss: 2.3025 - accuracy: 0.1023 - val_loss: 2.3027 - val_accuracy: 0.0933
# Epoch 3/150
# 313/313 [==============================] - 3s 11ms/step - loss: 2.3025 - accuracy: 0.1082 - val_loss: 2.3027 - val_accuracy: 0.0933
# Epoch 4/150
# 313/313 [==============================] - 5s 15ms/step - loss: 2.3024 - accuracy: 0.1091 - val_loss: 2.3027 - val_accuracy: 0.0933
# Epoch 5/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.3024 - accuracy: 0.1081 - val_loss: 2.3027 - val_accuracy: 0.0933
# Epoch 6/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.3022 - accuracy: 0.1094 - val_loss: 2.3026 - val_accuracy: 0.0933
# Epoch 7/150
# ...

# %%
relu_model_G = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'relu', initializer = "glorot_uniform")
relu_history_G = relu_model_G.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
relu_loss_G, softsign_accuracy_G = relu_model_G.evaluate(X_test, y_test)
display_loss(relu_history_G)
display_accuracy(relu_history_G)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 60s 16ms/step - loss: 2.3071 - accuracy: 0.1087 - val_loss: 2.2912 - val_accuracy: 0.1347
# Epoch 2/150
# 313/313 [==============================] - 3s 11ms/step - loss: 2.2811 - accuracy: 0.1267 - val_loss: 2.2705 - val_accuracy: 0.1738
# Epoch 3/150
# 313/313 [==============================] - 4s 11ms/step - loss: 2.2551 - accuracy: 0.1452 - val_loss: 2.2367 - val_accuracy: 0.1699
# Epoch 4/150
# 313/313 [==============================] - 4s 12ms/step - loss: 2.2308 - accuracy: 0.1532 - val_loss: 2.2113 - val_accuracy: 0.1779
# Epoch 5/150
# 313/313 [==============================] - 4s 14ms/step - loss: 2.2069 - accuracy: 0.1576 - val_loss: 2.2098 - val_accuracy: 0.1695
# Epoch 6/150
# 313/313 [==============================] - 4s 12ms/step - loss: 2.1920 - accuracy: 0.1595 - val_loss: 2.1761 - val_accuracy: 0.1754
# Epoch 7/150
# ...

# %%
relu_model_H = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'relu', initializer = "he_normal")
relu_history_H = relu_model_H.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
relu_loss_H, softsign_accuracy_H = relu_model_H.evaluate(X_test, y_test)
display_loss(relu_history_H)
display_accuracy(relu_history_H)
# Out:
# Epoch 1/150
# 313/313 [==============================] - 6s 16ms/step - loss: 2.3221 - accuracy: 0.1037 - val_loss: 2.3017 - val_accuracy: 0.1148
# Epoch 2/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.3026 - accuracy: 0.1049 - val_loss: 2.2992 - val_accuracy: 0.1237
# Epoch 3/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.3015 - accuracy: 0.1041 - val_loss: 2.3015 - val_accuracy: 0.1069
# Epoch 4/150
# 313/313 [==============================] - 4s 13ms/step - loss: 2.2993 - accuracy: 0.1131 - val_loss: 2.2920 - val_accuracy: 0.1581
# Epoch 5/150
# 313/313 [==============================] - 4s 12ms/step - loss: 2.2913 - accuracy: 0.1211 - val_loss: 2.2892 - val_accuracy: 0.1434
# Epoch 6/150
# 313/313 [==============================] - 3s 10ms/step - loss: 2.2781 - accuracy: 0.1340 - val_loss: 2.2827 - val_accuracy: 0.1554
# Epoch 7/150
# ...

# %% [markdown]
# # **Leaky Relu**
# ## **MODEL1**

# %%
# leaky_relu_model_S = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'leaky_relu', initializer = "random_uniform")
# leaky_relu_history_S = leaky_relu_model_S.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
# leaky_relu_loss_S, softsign_accuracy_S = leaky_relu_model_S.evaluate(X_test, y_test)
# display_loss(leaky_relu_history_S)
# display_accuracy(leaky_relu_history_S)

# %%
# leaky_relu_model_G = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'leaky_relu', initializer = "glorot_uniform")
# leaky_relu_history_G = leaky_relu_model_G.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
# leaky_relu_loss_G, softsign_accuracy_ = leaky_relu_model_G.evaluate(X_test, y_test)
# display_loss(leaky_relu_history_G)
# display_accuracy(leaky_relu_history_G)

# %%
# leaky_relu_model_H = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'leaky_relu', initializer = "he_normal")
# leaky_relu_history_H = leaky_relu_model_H.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
# leaky_relu_loss_H, softsign_accuracy_ = leaky_relu_model_H.evaluate(X_test, y_test)
# display_loss(leaky_relu_history_H)
# display_accuracy(leaky_relu_history_H)

# %% [markdown]
# # **PRelu**
# ## **MODEL1**

# %%
# p_relu_model_S = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'prelu', initializer = "random_uniform")
# p_relu_history_S = p_relu_model_S.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
# p_relu_loss_S, softsign_accuracy_S = p_relu_model_S.evaluate(X_test, y_test)
# display_loss(p_relu_history_S)
# display_accuracy(p_relu_history_S)

# %%
# p_relu_model_G = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'prelu', initializer = "glorot_uniform")
# p_relu_history_G = p_relu_model_G.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
# p_relu_loss_G, softsign_accuracy_G = p_relu_model_G.evaluate(X_test, y_test)
# display_loss(p_relu_history_G)
# display_accuracy(p_relu_history_G)

# %%
# p_relu_model_H = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 5, activation_func = 'prelu', initializer = "he_normal")
# p_relu_history_H = p_relu_model_H.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))
# p_relu_loss_H, softsign_accuracy_H = p_relu_model_H.evaluate(X_test, y_test)
# display_loss(p_relu_history_H)
# display_accuracy(p_relu_history_H)

# %% [markdown]
# # **$III.$ Kaiming He, Xiangyu Zhang, Shaoqing Ren, and Jian Sun initialization scheme**

# %%
from tensorflow import keras
from tensorflow.keras import initializers

def build_model(input_shape, hidden_size, output_size, number_of_hidden_layers, activation_func, initializer):
  model = keras.Sequential()

  model.add(keras.Input(shape=input_shape))

  for _ in range(number_of_hidden_layers):
    model.add(keras.layers.Dense(hidden_size, activation=activation_func, kernel_initializer=initializer))
    model.add(keras.layers.Dropout(0.5))

  model.add(keras.layers.Dense(output_size, activation="softmax"))

  model.compile(optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
  return model

from tensorflow import keras
from tensorflow.keras import initializers

def build_model_prelu(input_shape, hidden_size, output_size, number_of_hidden_layers, initializer):
  model = keras.Sequential()

  model.add(keras.Input(shape=input_shape))

  for _ in range(number_of_hidden_layers):
    model.add(keras.layers.Dense(hidden_size, kernel_initializer = initializer))
    model.add(keras.layers.Dropout(0.5))
    model.add(PReLU())

  model.add(keras.layers.Dense(output_size, activation="softmax"))

  model.compile(optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
  return model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Dense, Dropout, PReLU
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.optimizers import Adam

def make_model_XX( initializer, input_shape=(32, 32, 3), num_classes=10):

    model = Sequential()
    # model.add(Conv2D(24, (7, 7), strides=(2, 2), padding='same', input_shape=input_shape, kernel_initializer=initializer))
    # model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    # for _ in range(27):  # Adding 27 convolutional layers
        model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer=initializer))
        # model.add(PReLU())

    # model.add(GlobalAveragePooling2D())

    model.add(Dense(1024, kernel_initializer=initializer))
    model.add(Dropout(0.5))
    model.add(PReLU())
    model.add(Dense(1024, kernel_initializer=initializer))
    model.add(Dropout(0.5))
    model.add(PReLU())
    model.add(Dense(1024, kernel_initializer=initializer))
    model.add(Dropout(0.5))
    model.add(PReLU())

    model.add(Dense(num_classes, activation='softmax', kernel_initializer=initializer))

    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import PReLU
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.layers import GlobalAveragePooling2D  # Assuming Spatial Pyramid Pooling is similar

def make_model_X(initializer,input_shape=(32, 32, 3), num_classes=10):

    model = Sequential([
        Conv2D(96, (7, 7), strides=(2, 2), padding='same', input_shape=input_shape, kernel_initializer=initializer),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        Conv2D(256, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),

        GlobalAveragePooling2D(),

        Dense(4096, kernel_initializer=initializer),
        Dropout(0.5),
        PReLU(),
        Dense(4096, kernel_initializer=initializer),
        Dropout(0.5),
        PReLU(),
        Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import PReLU
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.layers import GlobalAveragePooling2D  # Assuming Spatial Pyramid Pooling is similar

def make_model_A(initializer,input_shape=(32, 32, 3), num_classes=10):
    """
    Builds a VGG19 inspired model architecture modified according to the paper,
    with PReLU activation and adjustments in convolutional layers' configuration.

    Args:
        input_shape: The shape of the input images (default: (224, 224, 3) for ImageNet).
        num_classes: The number of output classes (default: 1000 for ImageNet).

    Returns:
        A compiled Keras Sequential model.
    """

    model = Sequential([
        # First conv layer with modified filter size and stride according to the paper.
        Conv2D(24, (7, 7), strides=(2, 2), padding='same', input_shape=input_shape, kernel_initializer=initializer),
        PReLU(),

        # First pooling layer
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Second set of layers
        Conv2D(64, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(64, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(64, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(64, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(64, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third set of layers
        Conv2D(128, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(128, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(128, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(128, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(128, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third set of layers
        Conv2D(128, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(128, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(128, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(128, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(128, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),

        # Spatial Pyramid Pooling or similar global pooling
        GlobalAveragePooling2D(),

        # Fully-connected layers
        Dense(1024, kernel_initializer=initializer),
        Dropout(0.5),
        PReLU(),
        Dense(1024, kernel_initializer=initializer),
        Dropout(0.5),
        PReLU(),
        Dense(num_classes, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Example usage (assuming you have your image data loaded)
# model = modelA(input_shape=(224, 224, 3), num_classes=1000)
# model.fit(your_training_data, your_training_labels, epochs=your_epochs)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import PReLU
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.layers import GlobalAveragePooling2D  # Assuming Spatial Pyramid Pooling is similar

def make_model_B(initializer, input_shape=(32, 32, 3), num_classes=10):
    """
    Builds a VGG19 inspired model architecture modified according to the paper,
    with PReLU activation and adjustments in convolutional layers' configuration.

    Args:
        input_shape: The shape of the input images (default: (224, 224, 3) for ImageNet).
        num_classes: The number of output classes (default: 1000 for ImageNet).

    Returns:
        A compiled Keras Sequential model.
    """

    model = Sequential([
        # First conv layer with modified filter size and stride according to the paper.
        Conv2D(96, (7, 7), strides=(2, 2), padding='same', input_shape=input_shape, kernel_initializer=initializer),
        PReLU(),

        # First pooling layer
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Second set of layers
        Conv2D(256, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(256, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        #
        Conv2D(256, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third set of layers
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        #
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third set of layers
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        #
        Conv2D(512, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),

        # Spatial Pyramid Pooling or similar global pooling
        GlobalAveragePooling2D(),

        # Fully-connected layers
        Dense(4096, kernel_initializer=initializer),
        Dropout(0.5),
        PReLU(),
        Dense(4096, kernel_initializer=initializer),
        Dropout(0.5),
        PReLU(),
        Dense(num_classes, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Example usage (assuming you have your image data loaded)
# model = modelA(input_shape=(224, 224, 3), num_classes=1000)
# model.fit(your_training_data, your_training_labels, epochs=your_epochs)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import PReLU
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.layers import GlobalAveragePooling2D  # Assuming Spatial Pyramid Pooling is similar

def make_model_C(initializer, input_shape=(32, 32, 3), num_classes=10):
    """
    Builds a VGG19 inspired model architecture modified according to the paper,
    with PReLU activation and adjustments in convolutional layers' configuration.

    Args:
        input_shape: The shape of the input images (default: (224, 224, 3) for ImageNet).
        num_classes: The number of output classes (default: 1000 for ImageNet).

    Returns:
        A compiled Keras Sequential model.
    """

    model = Sequential([
        # First conv layer with modified filter size and stride according to the paper.
        Conv2D(96, (7, 7), strides=(2, 2), padding='same', input_shape=input_shape, kernel_initializer=initializer),
        PReLU(),

        # First pooling layer
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Second set of layers
        Conv2D(384, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(384, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(384, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(384, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(384, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        #
        Conv2D(384, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third set of layers
        Conv2D(768, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(768, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(768, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(768, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(768, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        #
        Conv2D(768, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),

        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third set of layers
        Conv2D(896, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(896, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(896, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(896, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        Conv2D(896, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),
        #
        Conv2D(896, (3, 3), padding='same', kernel_initializer=initializer),
        PReLU(),

        # Spatial Pyramid Pooling or similar global pooling
        GlobalAveragePooling2D(),

        # Fully-connected layers
        Dense(4096, kernel_initializer=initializer),
        Dropout(0.5),
        PReLU(),
        Dense(4096, kernel_initializer=initializer),
        Dropout(0.5),
        PReLU(),
        Dense(num_classes, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Example usage (assuming you have your image data loaded)
# model = modelA(input_shape=(224, 224, 3), num_classes=1000)
# model.fit(your_training_data, your_training_labels, epochs=your_epochs)

# %%
from tensorflow import random
from tensorflow.keras import initializers

class RandomUniformInitializer(initializers.Initializer):
  def __init__(self, seed=None):
    self.seed = seed

  def __call__(self, shape, dtype=None):
    if self.seed is not None:
      random.set_seed(self.seed)
    limit = 1.0 / np.sqrt(shape[-1])
    return random.uniform(shape, minval=-limit, maxval=limit, dtype=dtype)

# %%
#Based on the paper, page 250-251, part 2.3, we computed negative log_liklihood over 10 consecutive training pairs (x, y) and used to update parameters θ in that direction
batch_size = 128
epochs = 60

# %% [markdown]
# ## **$IV.$ Compare two initialization schemes**

# %%
modelA = make_model_XX(initializer = 'glorot_uniform')

historyA = modelA.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

lossA, accuracyA = modelA.evaluate(X_test, y_test)

display_accuracy(historyA)
display_loss(historyA)

# %%
modelA = make_model_XX(initializer = 'he_normal')

historyA = modelA.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

lossA, accuracyA = modelA.evaluate(X_test, y_test)

display_accuracy(historyA)
display_loss(historyA)

# %%
modelA = make_model_A(initializer = HeNormal())

historyA = modelA.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

lossA, accuracyA = modelA.evaluate(X_test, y_test)

display_accuracy(historyA)
display_loss(historyA)

# %%
modelB = make_model_B(initializer = 'he_normal')

historyB = modelB.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

lossB, accuracyB = modelB.evaluate(X_test, y_test)

display_accuracy(historyB)
display_loss(historyB)

# %%
modelC = make_model_C()

historyC = modelC.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val))

lossC, accuracyC = modelC.evaluate(X_test, y_test)

display_accuracy(historyC)
display_loss(historyC)

# %%
batch_size = 128
epochs = 80

# %%
# Flatten the images and normalize the pixel values
X_train = X_train.reshape(-1, 32* 32*3)
X_val = X_val.reshape(-1, 32* 32*3)
X_test = X_test.reshape(-1, 32* 32*3)

#Normalize the pixel values
# X_train = X_train / 255.0
# X_val = X_val / 255.0
# X_test = X_test / 255.0

# %%
import tensorflow

sigmoid_model_S = build_model(input_shape = (32*32*3,), hidden_size = 100, output_size = 10, number_of_hidden_layers = 4, activation_func = 'sigmoid', initializer = RandomUniformInitializer())


def train_model(model):
  # Lists to store activation statistics for each epoch
  losses = []
  val_losses = []
  accuracies = []
  val_accuracies = []
  means_per_epoch = []
  stds_per_epoch = []
  percentiles_per_epoch = []

  # Training loop
  for epoch in range(epochs):
      # Create a data generator for the training set
      train_data_gen = tensorflow.data.Dataset.from_tensor_slices((X_train, y_train)).batch(batch_size)

      # Get the activations for each layer
      activations = []
      layer_outputs = []
      for layer in model.layers:
          if isinstance(layer, keras.layers.Dense):
              layer_outputs.append([])

      for inputs, targets in train_data_gen:
          layer_input = inputs
          for i, layer in enumerate(model.layers):
              if isinstance(layer, keras.layers.Dense):
                  output = layer(layer_input)
                  layer_outputs[i//2].append(output.numpy().flatten())
                  layer_input = output

      # Calculate the mean, standard deviation, and percentiles for each layer
      means = []
      stds = []
      percentiles = []
      for activations_layer in layer_outputs:
          activations_layer = np.concatenate(activations_layer)
          means.append(np.mean(activations_layer))
          stds.append(np.std(activations_layer))
          percentiles.append(np.percentile(activations_layer, 98))

      # Store the statistics for this epoch
      means_per_epoch.append(means)
      stds_per_epoch.append(stds)
      percentiles_per_epoch.append(percentiles)

      # Fit the model for this epoch
      print(f"Epoch: {epoch+1} / {epochs}")
      sigmoid_history_S = model.fit(X_train, y_train, batch_size=batch_size, epochs=1, validation_data=(X_val, y_val))

      losses.append(sigmoid_history_S.history['loss'])
      accuracies.append(sigmoid_history_S.history['accuracy'])
      val_losses.append(sigmoid_history_S.history['val_loss'])
      val_accuracies.append(sigmoid_history_S.history['val_accuracy'])
  return losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch

# Plot the results

# %%
losses, val_losses, accuracies, val_accuracies, means_per_epoch, stds_per_epoch, percentiles_per_epoch = train_model(sigmoid_model_S)
sigmoid_loss_G, sigmoid_accuracy_G = sigmoid_model_S.evaluate(X_test, y_test)

# %%
import matplotlib.pyplot as plt

def plot_loss_acc(losses, val_losses, accuracies, val_accuracies):
  plt.figure(figsize=(12, 6))
  plt.subplot(1, 2, 1)
  plt.plot(range(1, epochs+1), losses, label='Training Loss')
  plt.plot(range(1, epochs+1), val_losses, label='Validation Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.title('Training Loss')
  plt.legend()

  plt.subplot(1, 2, 2)
  plt.plot(range(1, epochs+1), accuracies, label='Training Accuracy')
  plt.plot(range(1, epochs+1), val_accuracies, label='Validation Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.title('Training Accuracy')
  plt.legend()

plot_loss_acc(losses, val_losses, accuracies, val_accuracies)

# %%
import matplotlib.cm as cm  # Import colormap
def plot_activation_values(model, means_per_epoch, stds_per_epoch, percentiles_per_epoch):
  fig, ax1 = plt.subplots(figsize=(20, 6))
  num_dense_layers = sum(1 for layer in model.layers if isinstance(layer, keras.layers.Dense))

  colors = cm.rainbow(np.linspace(0, 1, num_dense_layers))
  skip_first = True

  for i, (layer, color) in enumerate(zip(model.layers, colors)):
    if(skip_first):
        skip_first = False
        continue
    if isinstance(layer, keras.layers.Dense):
        layer_means = [means_per_epoch[epoch][i] for epoch in range(epochs)]
        layer_stds = [stds_per_epoch[epoch][i] for epoch in range(epochs)]
        layer_percentiles = [percentiles_per_epoch[epoch][i] for epoch in range(epochs)]

        ax1.plot(range(1, epochs+1), layer_means, label=f'Mean (Layer {i+1})', color=color)
        ax1.errorbar(range(1, epochs+1), layer_means, yerr=layer_stds, fmt='.', color=color, label=f'Std Dev (Layer {i+1})')

  ax1.set_xlabel('Epoch')
  ax1.set_ylabel('Activation Value')
  ax1.set_title('Activation Value Statistics')
  ax1.legend()

  plt.show()

# %%
import matplotlib.cm as cm  # Import colormap
fig, ax1 = plt.subplots(figsize=(20, 6))

model = sigmoid_model_S

num_dense_layers = sum(1 for layer in model.layers if isinstance(layer, keras.layers.Dense))

colors = cm.rainbow(np.linspace(0, 1, num_dense_layers))
skip_first = True

for i, (layer, color) in enumerate(zip(model.layers, colors)):
    # if(skip_first):
    #   skip_first = False
    #   continue
    if isinstance(layer, keras.layers.Dense):
        layer_means = [means_per_epoch[epoch][i] for epoch in range(epochs)]
        layer_stds = [stds_per_epoch[epoch][i] for epoch in range(epochs)]
        layer_percentiles = [percentiles_per_epoch[epoch][i] for epoch in range(epochs)]

        ax1.plot(range(1, epochs+1), layer_means, label=f'Mean (Layer {i+1})', color=color)
        ax1.errorbar(range(1, epochs+1), layer_means, yerr=layer_stds, fmt='.', color=color, label=f'Std Dev (Layer {i+1})')
        ax1.plot(range(1, epochs+1), layer_percentiles, '^', color=color, label=f'98th Percentile (Layer {i+1})')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Activation Value')
ax1.set_title('Activation Value Statistics')
ax1.legend()

plt.show()

# %% [markdown]
# The bars representing the standard deviation for the first layer appear larger than the others because the activations in the first layer tend to have a larger variance compared to the subsequent layers.
#
# This is a common phenomenon in neural networks, where the activations in the earlier layers (closer to the input) tend to have a higher variability or spread, while the activations in the later layers become more stable and have a smaller variance.
#
# There are a few reasons why this happens:
#
# 1. **Input Distribution**: The activations in the first layer are directly influenced by the input data distribution, which can be quite diverse and have a large range of values, leading to higher variance in the activations.
#
# 2. **Weight Initialization**: The initial weights in the first layer are randomly initialized, which can introduce higher variability in the activations compared to later layers, where the weights have been optimized during training.
#
# 3. **Feature Extraction**: The early layers in a neural network are responsible for extracting low-level features from the input data, which can result in a wider range of activation values as the network learns to represent different patterns and features.
#
# 4. **Normalization**: Later layers in the network often benefit from the normalization or regularization techniques applied to the activations, such as batch normalization or dropout, which can reduce the variance and stabilize the activations.

# %%
plot_activation_values(sigmoid_model_S, means_per_epoch, stds_per_epoch, percentiles_per_epoch)

# %%
# def make_relu(alpha):  # Define a custom Leaky ReLU function with learnable alpha
#   def activate(x):
#     return keras.activations.relu(x, alpha=alpha)
#   return activate

# leaky_relu = make_relu(alpha=0.01)
# prelu = make_relu(alpha=0.25)
